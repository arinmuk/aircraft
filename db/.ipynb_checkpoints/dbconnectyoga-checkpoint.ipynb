# %%
import sys
import pandas as pd
import pyodbc as pyodbc
from sqlalchemy.dialects.mssql import pymssql
import sqlalchemy
import pymssql
import pymongo
import csv
import json
from pymongo import MongoClient
from flask import Flask, jsonify, render_template
client = MongoClient()
client = MongoClient('localhost', 27017)
#import mysql as mysql

# %%
servername='LAPTOP-HIB8VNLH'
#servername='asus-i7'
username='arindam'
#pwd=input(" enter password : ")
pwd="Airbusa350xwb"
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])
es
# Out:
# <Elasticsearch([{'host': 'localhost', 'port': 9200}])>

# %%
def sqlread():
    conn = pymssql.connect(server=servername, user=username, password=pwd, database='aircraft') 
    cursor = conn.cursor()
    qry='SELECT * from aircraft'
    salesqry='select s.*,a.price,a.shipping,a.tax from solddetails s inner join aircraftsold a on s.aircraftid=a.id '
    cursor.execute('SELECT * from aircraft')
    cursor.execute(salesqry)
    row = cursor.fetchone()  
    #while row:  
            #print(row)
            #row = cursor.fetchone()  
    sqldf=pd.read_sql(qry,conn)
    solddf=pd.read_sql(salesqry,conn)
    sqldf.head()
    return sqldf,solddf

# %%
sqldf,solddf = sqlread()
solddf.head()
solddf["profit_loss"]=solddf["NetRecd"]-(solddf["price"]+solddf["shipping"]+solddf["tax"])
solddf["SaleDate"]=pd.to_datetime(solddf["SaleDate"])
solddf["month"]=solddf['SaleDate'].dt.month
solddf["year"]=solddf['SaleDate'].dt.year
solddf.head()
solddf.set_index("SaleDate",inplace=True)
solddf.head()
sqldf.columns
calcdf = sqldf.drop(['DIMAID', 'WID','DESCRIPTION', 'PICTURE', 'Picture2',
       'Picture3', 'Rare', 'HangarClub', 'MarketValue', 'PictureID'],axis =1)
exportdf=sqldf.drop(['PICTURE', 'Picture2',
       'Picture3', 'Rare', 'MarketValue'], axis =1)
filename="E:/aircraft/air.csv"
exportdf.to_csv(filename,index=None,header=False,encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# MSSQLDriverException                      Traceback (most recent call last)
# src\pymssql.pyx in pymssql.connect()
#
# src\_mssql.pyx in _mssql.connect()
#
# src\_mssql.pyx in _mssql.MSSQLConnection.__init__()
#
# MSSQLDriverException: Connection to the database failed for an unknown reason.
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-13-e657bb6cc35f> in <module>
# ----> 1 sqldf,solddf = sqlread()
#       2 solddf.head()
#       3 solddf["profit_loss"]=solddf["NetRecd"]-(solddf["price"]+solddf["shipping"]+solddf["tax"])
#       4 solddf["SaleDate"]=pd.to_datetime(solddf["SaleDate"])
#       5 solddf["month"]=solddf['SaleDate'].dt.month
#
# <ipython-input-12-2ce44b204d9e> in sqlread()
#       1 def sqlread():
# ----> 2     conn = pymssql.connect(server=servername, user=username, password=pwd, database='aircraft')
#       3     cursor = conn.cursor()
#       4     qry='SELECT * from aircraft'
#       5     salesqry='select s.*,a.price,a.shipping,a.tax from solddetails s inner join aircraftsold a on s.aircraftid=a.id '
#
# src\pymssql.pyx in pymssql.connect()
#
# InterfaceError: Connection to the database failed for an unknown reason.

# %%
def mongoR_I(exportdf,soldf):
    db=client['Aircraft']
    colmodels=db['models']
    colmodels2=db['models2']
    colsales=db['sales']
    cursor = colmodels.find() 
#for record in cursor: 
    colmodels.drop()
    
    colmodels2.drop()
    colsales.drop()
    #records = json.loads(exportdf.to_json(orient='records'))
    #records = json.loads(exportdf.T.to_json()).values()
    #db.models.insert_many(records)
    #db.insert_many(df.to_dict('records'))
    db.models.insert_many(exportdf.to_dict('records'))
    db.models2.insert_many(exportdf.to_dict('records'))
    db.sales.insert_many(soldf.to_dict('records'))

# %%
awsstr='mongodb+srv://arinmuk:amarji123!@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority'
awsclient=MongoClient()
awsclient=MongoClient(awsstr)
db=client['Aircraft']
colmodels=db['models']
colmodels2=db['models2']
colsales=db['sales']
cursor = colmodels.find() 
#for record in cursor: 
colmodels.drop()

colmodels2.drop()
colsales.drop()
#records = json.loads(exportdf.to_json(orient='records'))
#records = json.loads(exportdf.T.to_json()).values()
#db.models.insert_many(records)
#db.insert_many(df.to_dict('records'))
db.models.insert_many(exportdf.to_dict('records'))
db.models2.insert_many(exportdf.to_dict('records'))
db.sales.insert_many(soldf.to_dict('records'))
#client = MongoClient()
#client = MongoClient('localhost', 27017)

# %%
def elastic_update(exportdf,solddf):
    es.indices.delete(index='aircraft')
    es.indices.delete(index='aircraft_sales')
    es.indices.create(index='aircraft', ignore=400)
    es.indices.create(index='aircraft_sales', ignore=400)
    INDEX="aircraft"
    TYPE= "models"
    from bson import json_util

    def rec_to_actions(export1df):
        #export1df["DATEOFORDER"]=export1df['DATEOFORDER'].dt.strftime('%Y-%m-%d')
        import json
        tmp = export1df.to_json(orient = "records")
        print(tmp)
    # Load each record into json format before bulk
        df_json= json.loads(tmp)
        for record in df_json: #export1df.to_dict(orient="records"):
            #print(record)
            yield ('{ "index" : { "_index" : "%s", "_type" : "%s" }}'% (INDEX, TYPE))
            yield (json.dumps(record, default=str))

    #from elasticsearch import Elasticsearch
    #e = Elasticsearch() # no args, connect to localhost:9200
    if not es.indices.exists(INDEX):
        raise RuntimeError('index does not exists, use `curl -X PUT "localhost:9200/%s"` and try again'%INDEX)

    r = es.bulk(rec_to_actions(exportdf)) # return a dict
    INDEX="aircraft_sales"
    TYPE= "sold"
    r1= es.bulk(rec_to_actions(solddf)) # return a dict
    print(not r["errors"])

# %%
mongoR_I(exportdf,solddf)
elastic_update(exportdf,solddf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8bbea346f4bd> in <module>
# ----> 1 mongoR_I(exportdf,solddf)
#       2 elastic_update(exportdf,solddf)
#
# NameError: name 'mongoR_I' is not defined

# %%
exportdf.head()
#exportdf['DATEOFORDER']=(exportdf['DATEOFORDER'])
exportdf.head()
# Out:
#    ID  MODEL_NO  DIMAID    WID        AIRLINE AIRCRAFT_TYPE REGISTRATION  \
# 0   2  AC18022B     NaN   3873      AIR INDIA      B707-400       VT-DJI
# 1   3  HE502238     NaN  12793     KINGFISHER      A320-200       VT-KFA
# 2   7  DRW55934     NaN  13473  QATAR AIRWAYS      A330-200       A7-ACG
# 3  11    MP5805     NaN  17047      LUFTHANSA      A340-600           NA
# 4  12   AC4XEAJ     NaN  15977          EL AL    B767-300ER       4X-EAJ
#
#                                          DESCRIPTION   SIZE   PRICE  SHIPPING  \
# 0  Aeroclassics Air India B 707-437 1:400 - AC180...  1:400  122.00      20.0
# 1  Herpa Kingfisher Airlines A320-232 1:500 - 502...  1:500   26.00       3.0
# 2  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400   20.95       0.4
# 3  Model Power Lufthansa A340-642 1:500 - 5805 - ...  1:500   14.95       0.4
# 4  Aeroclassics El Al B 767-330ER 1:400 - AC4XEAJ...  1:400   15.00       1.0
#
#    TAX       COMPANY       ORDEREDFROM DATEOFORDER  HangarClub  PictureID
# 0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06       False        2.0
# 1  0.0         HERPA              DAC:  2011-02-06       False        3.0
# 2  0.0  DRAGON WINGS      3000toys.com  2011-02-04       False        6.0
# 3  0.0   MODEL POWER      3000TOYS.COM  2011-02-04       False       10.0
# 4  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02       False       12.0

# %%
exportdf.columns
exportdf["DATEOFORDER"]=pd.to_datetime(exportdf['DATEOFORDER'])
exportdf["DATEOFORDER"].dtype
# Out:
# dtype('<M8[ns]')

# %%
#db.models2.insert_many(records)
calcdf.head()
# Out:
#    ID  MODEL_NO        AIRLINE AIRCRAFT_TYPE REGISTRATION   SIZE   PRICE  \
# 0   2  AC18022B      AIR INDIA      B707-400       VT-DJI  1:400  122.00
# 1   3  HE502238     KINGFISHER      A320-200       VT-KFA  1:500   26.00
# 2   7  DRW55934  QATAR AIRWAYS      A330-200       A7-ACG  1:400   20.95
# 3  11    MP5805      LUFTHANSA      A340-600           NA  1:500   14.95
# 4  12   AC4XEAJ          EL AL    B767-300ER       4X-EAJ  1:400   15.00
#
#    SHIPPING  TAX       COMPANY       ORDEREDFROM DATEOFORDER
# 0      20.0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06
# 1       3.0  0.0         HERPA              DAC:  2011-02-06
# 2       0.4  0.0  DRAGON WINGS      3000toys.com  2011-02-04
# 3       0.4  0.0   MODEL POWER      3000TOYS.COM  2011-02-04
# 4       1.0  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02

# %%
airlinegrp=calcdf.groupby(['AIRLINE']).ID.agg(['count'])
airlinegrp.head(5)
airlinegrp=airlinegrp.rename(columns={'count':"total"})

airlinegrp.head()
airlinetotal=calcdf.groupby(['SIZE']).agg({'PRICE':['sum'],'ID':'count'}).rename(columns={'sum':"cost"})
airlinetotal.head(10)
# Out:
#             PRICE    ID
#              cost count
# SIZE
# 1:100     1127.98    13
# 1:1000      58.00     2
# 1:130      255.00     3
# 1:144      420.25     5
# 1:160        0.00     1
# 1:187       10.00     1
# 1:200   159388.31  2184
# 1:250       54.99     7
# 1:300      373.67     9
# 1:400   156263.70  4962

# %%
ai_df=calcdf[calcdf["AIRLINE"]=='air india'.upper()]
ai_df.head()
# Out:
#     ID  MODEL_NO    AIRLINE AIRCRAFT_TYPE REGISTRATION   SIZE  PRICE  \
# 0    2  AC18022B  AIR INDIA      B707-400       VT-DJI  1:400  122.0
# 15  32  IF743003  AIR INDIA      B747-300       VT-EPW  1:200   90.0
# 16  33  IF743003  AIR INDIA      B747-300       VT-EPW  1:200   90.0
# 58  85   ACVTDVB  AIR INDIA      B707-300       VT-DVB  1:400   33.0
# 64  91  AC18022B  AIR INDIA      B707-400       VT-DJI  1:400   35.0
#
#     SHIPPING  TAX       COMPANY         ORDEREDFROM DATEOFORDER
# 0       20.0  0.0  AEROCLASSICS    EBAY:marketa2218  2011-02-06
# 15       4.0  0.0   INFLIGHT200  EBAY:JOHANCHAN2004  2011-01-31
# 16       4.0  0.0   INFLIGHT200  EBAY:JOHANCHAN2004  2011-01-31
# 58       5.0  0.0  AEROCLASSICS       www.ebay.com:  2010-12-28
# 64       2.0  0.0  AEROCLASSICS        dac:jr lopez  2011-02-17

# %%
solddf.sort_index(inplace=True)
solddf["profit_loss"].plot()

# %%
solddf.index
# Out:
# DatetimeIndex(['2011-12-31', '2012-01-12', '2012-01-28', '2012-01-28',
#                '2012-02-15', '2012-03-03', '2012-03-03', '2012-03-03',
#                '2012-03-12', '2012-04-03',
#                ...
#                '2019-08-05', '2019-08-06', '2019-08-06', '2019-08-08',
#                '2019-08-12', '2019-08-15', '2019-08-22', '2019-08-22',
#                '2019-08-24', '2019-09-03'],
#               dtype='datetime64[ns]', name='SaleDate', length=1683, freq=None)

# %%
solddf["profit_loss"].rolling(30).mean().plot()

# %%
calcdf["AIRLINE"]=calcdf['AIRLINE'].str.title()
list(set(calcdf['AIRLINE'].values.tolist()))
# Out:
# ['Ltu',
#  'Ariana Afghan',
#  'Conviasa',
#  'Trump',
#  'Deer Air',
#  'Wow Air',
#  'Raaf',
#  'Huges Airwest',
#  'Thomas Cook Airlines',
#  'Ryukyu Air Commuter',
#  'Alaska Airlines',
#  'Freedom Air',
#  'Finlantic',
#  'Ana',
#  'Msa',
#  'Tap Air Portugal',
#  'Nal',
#  'German Cargo',
#  'Hapag Lloyd',
#  'Air Jamaica',
#  'Ethiopian Airlines',
#  'Virgin Blue',
#  'Jal Express',
#  'Soviet Air Force',
#  'Tam',
#  'Air Rhodesia',
#  'Air Zaire',
#  'Pacific Air',
#  'Japan Asia Airways',
#  'Northwest Orient',
#  'Binter Canarias',
#  'Air Caraïbes Atlantique',
#  'Hawaiian Airlines',
#  'Taesa',
#  'Russian Air Force',
#  'Fantasy',
#  'Canadian Pacific',
#  'Aer Lingus',
#  'Tarom',
#  'Maswings',
#  'Malaysian/Air Inter',
#  'Crossair',
#  'Republic Of Korea Airforc',
#  'Turkmenistan Airlines',
#  'Zas',
#  'Express.Net',
#  'America West',
#  'Jetstar Hongkong',
#  'Royal Air Maroc',
#  'Royal Nepal Airlines',
#  'Dragonair',
#  'Iberia',
#  'Martinair Holland',
#  'Pan American Grace Airway',
#  'Myair',
#  'Israir',
#  'Arrow Air',
#  'West Air',
#  'Fedex',
#  'Virgin Galactic',
#  'Jetstar Asia',
#  'Trans Global Airlines',
#  'Srilankan',
#  'British Eagle',
#  'Delta',
#  'Indigo',
#  'Virgin America',
#  'Transasia',
#  'Finnair',
#  'Aeromexico',
#  'Pelita Air',
#  'Zambian Airways',
#  'Uzbekistan Airways',
#  'American Airlines',
#  'Southwest',
#  'Sands Casino',
#  'Abx Air',
#  'Ata',
#  'Ups',
#  'Mas',
#  'Air California',
#  'Malaysia Airlines',
#  'Goair',
#  'Nokscoot',
#  'Cebu Pacific',
#  'Air Hongkong',
#  'Caac',
#  'Saudi Arabian',
#  'Vasp',
#  'Pia',
#  'Transbrasil',
#  'Hokkaido International',
#  'Air Koryo',
#  'Condor',
#  'Jetstar',
#  'Aeroflot',
#  'Astraeus',
#  'Alia',
#  'Iran Air',
#  'Mackey International',
#  'Britannia Airways',
#  'Polynesian Airlines',
#  'Tat',
#  'Latam',
#  'Air 2000',
#  'White',
#  'Air West',
#  'Seaboard World',
#  'Azul Linhas Aereas',
#  'Viasa',
#  'Jaz',
#  'Ansett Express',
#  'Indian Airforce',
#  'Mahan',
#  'Air Atlantic',
#  'Grand China Express',
#  'Corsair',
#  'Garuda Indonesia',
#  'A-Net',
#  'Song',
#  'Raf',
#  'Japan Sdf',
#  'Jal',
#  'South African',
#  'Panegra',
#  'Sas',
#  'American Inter Island',
#  'Quebecair',
#  'Ukraine International',
#  'Nca',
#  'Eva Air',
#  'New York Air',
#  'Silkair',
#  'Ukranian Airforce',
#  'Gator Global Flying',
#  'Playboy',
#  'United Express',
#  'Air France',
#  'Air Florida',
#  'Air Pullmantur',
#  'Aeroperu',
#  'Aerovias Q',
#  'Air India',
#  'Turkish Airlines',
#  'Emirates',
#  'Lockheed',
#  'Lam Mozambique',
#  'Fiji Airways',
#  'Patriots',
#  'Jat',
#  'Scoot',
#  'Nordair',
#  'Iraqi Airways',
#  'Virgin Nigeria',
#  'Mcdonnell Douglas',
#  'Air Liberte',
#  'Tower Air',
#  'Government Of Brunei',
#  'Surinam Airways',
#  'Bea',
#  'Air Europe',
#  'Avianova',
#  'Canadian Airlines',
#  'Airtran',
#  'Aerocondor',
#  'Kunpen',
#  'Cathay Pacific',
#  'Jade Cargo',
#  'Australia Asia Airlines',
#  'World Airways',
#  'Jalways',
#  'Edelweiss',
#  'Laker Airways',
#  'Compass Airlines',
#  'Virgin Samoa',
#  'Sky Airlines',
#  'Air Mauritius',
#  'Overseas National',
#  'Panair Do Brasil',
#  'Air Canada',
#  'Northeast',
#  'Air Congo',
#  'Taa',
#  'Royal Brunei',
#  'Delta Express',
#  'Swiss Air',
#  'Air Australia',
#  'National Airlines',
#  'Das Air Cargo',
#  'Pacific Blue',
#  'Kuzu Airlines',
#  'Dan Air',
#  'Luxair',
#  'Kuwait Airways',
#  'Lan Chile',
#  'Csa Czech Airlines',
#  'Tuifly.Com',
#  'Carcon',
#  'Lanica',
#  'Ryanair',
#  'Air Holland',
#  'Starflyer',
#  'Eastern Airlines',
#  'Northwest',
#  'Saha Air Lines',
#  'Delta Chicago & Southern',
#  'Thai Airasia',
#  'Royal Jordan',
#  'El Al',
#  'Air New Zealand',
#  'Varig',
#  'Air Pacific',
#  'Australian Air Express',
#  'Sun Country',
#  'Lauda Air',
#  'Sichuan Airlines',
#  'British Airways',
#  'Royal Aviation',
#  'Sukhoi Design Bureau',
#  'Kingfisher',
#  'Luftwaffe',
#  'Hongkong Express',
#  'Oman Air',
#  'Olympic',
#  'Russian Airforce',
#  'Ciskei International',
#  'Evergreen',
#  'Nigeria Airways',
#  'Ladeco',
#  'Monarch',
#  'Megantara',
#  'Tiger Airways Australia',
#  'Dhl',
#  'Ghana Airways',
#  'Gulf Traveller',
#  'Standard Airways',
#  'Interflug',
#  'Nlm',
#  'Sun Dor',
#  'Private',
#  'Air Bridge Cargo',
#  'Channel Air Bridge',
#  'Cathay Dragon',
#  'Air Seychelles',
#  'Virgin Sun',
#  'Republic Airlines',
#  'Indian Navy',
#  'Aeromaritime',
#  'Panam',
#  'Air Ceylon',
#  'Air Namibia',
#  'Braniff',
#  'Ank',
#  'Scanair',
#  'Germainia',
#  'American Eagle',
#  'Universal Airlines',
#  'Qantas',
#  'Pba',
#  'Icelandair',
#  'Western Pacific',
#  'Adria',
#  'Aerosur',
#  'Capitol Airways',
#  'Blank',
#  'Slovakia Airforce',
#  'Spanair',
#  'Qatar Airways',
#  'Skymark Airlines',
#  'Saudi Arabian Government',
#  'Pluna',
#  'Air Austral',
#  'Lot',
#  'Air Cote D Ivoire',
#  'Western Airlines',
#  'Etihad Airways',
#  'Iron Annie',
#  'Comair',
#  'Skyeurope',
#  'Iberia Express',
#  'Venezuelan Airforce',
#  'Aeronaves De Mexico',
#  'Tui Airlines',
#  'East Line Airlines',
#  'Qubecair',
#  'Trans Carribean Airways',
#  'Rossiya',
#  'Cp Air',
#  'Sobelair',
#  'Tunis Air',
#  'Air America',
#  'Transaero Airlines',
#  'Northwest Territorial',
#  'Jet Airways',
#  'Kalitta Air',
#  'Royal Thai Air Force',
#  'Brussels Airlines',
#  'United',
#  'Fantasy Aetna',
#  'British Airtours',
#  'Merpati Nusantara',
#  'Air Tahiti',
#  'Usair',
#  'Jaa',
#  'Taag',
#  'China Northern',
#  'Uta',
#  'Air Berlin',
#  'Australian',
#  'Air India Express',
#  'K Mile',
#  'Transamerica',
#  'British Asia Airways',
#  'Peoplexpress',
#  'Nok Air',
#  'Alitalia',
#  'Us Navy',
#  'Aerospatiale',
#  'Tiger Airways',
#  'Allegheny Airlines',
#  'Norwegian',
#  'Virgin Nigeria Airways',
#  'Flying Tigers',
#  'Air Niugini',
#  'Silkway Airlines',
#  'Us Airways',
#  'Jettrain',
#  'Polet Aviakompania',
#  'Air Greenland',
#  'Royal Jordanian',
#  'Frontier Airlines',
#  'Easyjet',
#  'Phuket Airlines',
#  'Utair',
#  'Syrianair',
#  'Aerolineas Argentinas',
#  'Civil Air Transport',
#  'Air Inter',
#  'Mandarin',
#  'Hi Fly',
#  'Continental',
#  'Singapore Airlines',
#  'Douglas Aircraft Company',
#  'Bangkok Airways',
#  'Tnt',
#  'Virgin Australia',
#  'Avensa',
#  'South African Airforce',
#  'Orient Thai',
#  'Skywest Airlines',
#  'Avianca',
#  'Klm',
#  'Spirit Airlines',
#  'Sudan Airways',
#  'Air Afrique',
#  'Air Madagascar',
#  'Thomson Airways',
#  'Ansett Australia',
#  'Antonov Design Bureau',
#  'Mexicana',
#  'Psa',
#  'Cruzeiro',
#  'Sabena',
#  'Asiana Airlines',
#  'V Australia',
#  'Afriqiyah Airways',
#  'Hungarian Airforce',
#  'Aloha Airlines',
#  'Jetblue',
#  'Boac',
#  'Ansett New Zealand',
#  'Bmi',
#  'Atlantic Airlines',
#  'Spicejet',
#  'Bahamasair',
#  'Amiri Flight',
#  'Ecuatoriana',
#  'Northeastern',
#  'Air Uk',
#  'China Airlines',
#  'Kenya Airways',
#  'Trans Canada Airlines',
#  'Kmv',
#  'China Southern',
#  'Real Transportes Aereos',
#  'Atlas Air',
#  'Horizon Air',
#  'Qantaslink',
#  'Volaris',
#  'Northwest Airlink',
#  'Amakusa',
#  'Iaf',
#  'Eastern',
#  'Novair',
#  'Pb Air',
#  'Gulf Air',
#  'Vietnam Airlines',
#  'Hinduja Cargo',
#  'Allegiant Air',
#  'Westjet',
#  'Cargolux',
#  'Nasa',
#  'Air Zimbabwe',
#  'Mandala Airlines',
#  'European Aircharter',
#  'Thai Airways',
#  'Boeing',
#  'Zambia Airways',
#  'Tibet Airlines',
#  'Royal Air Force',
#  'Air Transat',
#  'Usaf',
#  'Shanghai Airlines',
#  'Caledonian Airways',
#  'China Eastern',
#  'Philippine Airlines',
#  'Columbia Airlines',
#  'Aero California',
#  'Virgin Atlantic',
#  'Korean Air',
#  'Atlant-Soyuz Airlines',
#  'Royal Australian Af',
#  'Twa',
#  'Global Aviation Leasing',
#  'Austrian Airlines',
#  'Cubana',
#  'Jetstar Japan',
#  'Indian Airlines',
#  'Airborne Express',
#  'Flydubai',
#  'Ozark Airlines',
#  'Air China',
#  'Air Tanzania',
#  'Heavylift',
#  'Air Nippon',
#  'Egypt Air',
#  'Sf Airlines',
#  'Oceanair',
#  'Air Asia',
#  'Buffalo Airways',
#  'Avianca Colombia',
#  'Shenzhen Airlines',
#  'Avianca Brazil',
#  'Piedmont',
#  'Liat',
#  'British Caledonian',
#  'Hainan Airlines',
#  'Hongkong Airlines',
#  'Malev',
#  'Air Caraibes',
#  'La Dodgers',
#  'Mea',
#  'Swissair',
#  'Dachser',
#  'Casino Express',
#  'Kazakhstan Airforce',
#  'Bwia',
#  'Biman Bangladesh',
#  'Air Europa',
#  'Jas',
#  'Lufthansa',
#  'Ati',
#  'Wardair',
#  'Drax Air',
#  'Air Charter',
#  'Airbus']

# %%
calcdf["AIRLINE"].unique()
# Out:
# array(['Air India', 'Kingfisher', 'Qatar Airways', 'Lufthansa', 'El Al',
#        'Ana', 'Panam', 'Canadian Pacific', 'Garuda Indonesia',
#        'American Airlines', 'Qantas', 'Jal', 'Cp Air', 'Air New Zealand',
#        'Air Europe', 'Klm', 'Air France', 'Thai Airways', 'Air Canada',
#        'Northwest', 'British Airways', 'Emirates', 'Austrian Airlines',
#        'Air China', 'Airbus', 'South African', 'Continental',
#        'Qantaslink', 'Cathay Pacific', 'National Airlines',
#        'Singapore Airlines', 'Iberia', 'Virgin Atlantic',
#        'Transaero Airlines', 'Jet Airways', 'Iaf', 'Air India Express',
#        'Arrow Air', 'Etihad Airways', 'Malaysia Airlines', 'Carcon',
#        'Air Berlin', 'Egypt Air', 'Turkish Airlines', 'Flying Tigers',
#        'Boeing', 'Mandarin', 'Fedex', 'Spicejet', 'Air Liberte', 'Pia',
#        'United', 'Jalways', 'Sabena', 'Indian Airlines',
#        'Tap Air Portugal', 'Gulf Air', 'Gulf Traveller', 'Virgin Blue',
#        'Alaska Airlines', 'Twa', 'Varig', 'Aerolineas Argentinas', 'Song',
#        'Cubana', 'Delta', 'Eva Air', 'Jat', 'Air Pacific', 'Germainia',
#        'Swissair', 'Braniff', 'Condor', 'Dachser', 'Luftwaffe',
#        'Ghana Airways', 'Jaa', 'K Mile', 'Aeronaves De Mexico',
#        'Air 2000', 'Korean Air', 'Alitalia', 'America West', 'Ata',
#        'Finnair', 'Hawaiian Airlines', 'Hokkaido International', 'Luxair',
#        'Overseas National', 'Royal Aviation', 'Ups',
#        'Australia Asia Airlines', 'Virgin Nigeria Airways', 'Lan Chile',
#        'Lauda Air', 'China Airlines', 'Asiana Airlines', 'Oceanair',
#        'Mas', 'Scanair', 'Afriqiyah Airways', 'V Australia', 'Bwia',
#        'Air Jamaica', 'China Eastern', 'Air Caraïbes Atlantique', 'Lot',
#        'Air Asia', 'Aeroflot', 'Skymark Airlines', 'Biman Bangladesh',
#        'Atlas Air', 'Aer Lingus', 'Spirit Airlines', 'Northwest Orient',
#        'Western Pacific', 'Bmi', 'Binter Canarias', 'Southwest',
#        'Thomson Airways', 'Air Austral', 'Hainan Airlines', 'Olympic',
#        'Canadian Airlines', 'Airborne Express', 'Ansett Australia',
#        'Kalitta Air', 'Sas', 'Aerosur', 'Japan Asia Airways', 'Israir',
#        'Northeast', 'Sobelair', 'Caledonian Airways', 'Air Hongkong',
#        'Air Uk', 'New York Air', 'Britannia Airways', 'Monarch',
#        'Sudan Airways', 'Jal Express', 'Polynesian Airlines',
#        'Bangkok Airways', 'German Cargo', 'Nasa', 'Sky Airlines',
#        'Skywest Airlines', 'Shenzhen Airlines', 'Sichuan Airlines',
#        'Air Charter', 'Air Niugini', 'Dragonair', 'Easyjet',
#        'Cebu Pacific', 'Hinduja Cargo', 'Megantara',
#        'Philippine Airlines', 'Air Seychelles', 'Air Tanzania',
#        'Tiger Airways', 'Tiger Airways Australia', 'Viasa',
#        'Air Pullmantur', 'Australian', 'Jetstar', 'Virgin America',
#        'Pacific Blue', 'Royal Air Maroc', 'Royal Jordan', 'Virgin Sun',
#        'Taa', 'Maswings', 'Nal', 'Starflyer', 'Air Europa', 'Avianca',
#        'Jas', 'Nca', 'Tam', 'Tuifly.Com', 'Amiri Flight', 'Pelita Air',
#        'Merpati Nusantara', 'Us Airways', 'Das Air Cargo',
#        'Csa Czech Airlines', 'Orient Thai', 'Eastern Airlines',
#        'Grand China Express', 'Air Inter', 'Virgin Australia',
#        'Mandala Airlines', 'Boac', 'Deer Air', 'West Air',
#        'British Asia Airways', 'Mea', 'Saudi Arabian', 'Edelweiss',
#        'Usaf', 'Alia', 'Srilankan', 'Corsair', 'Wardair', 'Fantasy',
#        'Uzbekistan Airways', 'China Southern', 'Myair', 'Playboy',
#        'Skyeurope', 'Aloha Airlines', 'Laker Airways', 'Interflug',
#        'Ciskei International', 'Martinair Holland', 'Caac',
#        'British Airtours', 'World Airways', 'Uta', 'Royal Brunei',
#        'Transbrasil', 'Crossair', 'Horizon Air', 'Kenya Airways',
#        'Hapag Lloyd', 'Surinam Airways', 'La Dodgers',
#        'European Aircharter', 'Air Afrique', 'Kuwait Airways',
#        'China Northern', 'Columbia Airlines', 'Air California', 'Lanica',
#        'Adria', 'Zas', 'Msa', 'Mexicana', 'Express.Net',
#        'Shanghai Airlines', 'Kuzu Airlines', 'Air Nippon', 'Aerospatiale',
#        'Ati', 'Malaysian/Air Inter', 'Delta Express', 'Standard Airways',
#        'Casino Express', 'Tnt', 'Antonov Design Bureau',
#        'Trans Canada Airlines', 'Conviasa', 'Freedom Air', 'Ecuatoriana',
#        'Tibet Airlines', 'Virgin Galactic', 'Dhl', 'Pb Air', 'Taag',
#        'Atlant-Soyuz Airlines', 'White', 'Civil Air Transport',
#        'American Eagle', 'Saha Air Lines', 'Air Australia', 'Cargolux',
#        'Thai Airasia', 'American Inter Island', 'Scoot', 'Evergreen',
#        'Oman Air', 'Goair', 'Nigeria Airways', 'Virgin Samoa',
#        'Iberia Express', 'British Caledonian', 'Northwest Airlink',
#        'Australian Air Express', 'Airtran', 'Seaboard World', 'Ladeco',
#        'Psa', 'Pacific Air', 'Air West', 'Ethiopian Airlines',
#        'Jetstar Japan', 'Ank', 'Air Bridge Cargo', 'Heavylift',
#        'Compass Airlines', 'Tower Air', 'Aeromaritime', 'Jade Cargo',
#        'Kunpen', 'Tat', 'Soviet Air Force', 'Jetstar Asia',
#        'Jetstar Hongkong', 'Nordair', 'Bea', 'Ansett New Zealand',
#        'Drax Air', 'Air Atlantic', 'Qubecair', 'Atlantic Airlines',
#        'Huges Airwest', 'Transamerica', 'Quebecair',
#        'Northwest Territorial', 'Air Mauritius', 'Nlm', 'Nok Air',
#        'Cruzeiro', 'Kmv', 'Malev', 'Russian Airforce', 'Iraqi Airways',
#        'Zambia Airways', 'Northeastern', 'Aeroperu', 'Pluna', 'Indigo',
#        'Tunis Air', 'Aeromexico', 'East Line Airlines',
#        'Turkmenistan Airlines', 'Delta Chicago & Southern', 'Avianova',
#        'Douglas Aircraft Company', 'Global Aviation Leasing',
#        'Mcdonnell Douglas', 'Royal Air Force', 'British Eagle',
#        'Republic Airlines', 'Ryukyu Air Commuter', 'A-Net',
#        'Phuket Airlines', 'Ryanair', 'Amakusa', 'Transasia', 'Norwegian',
#        'Air Zaire', 'Jaz', 'Blank', 'Raf', 'Virgin Nigeria',
#        'Air Madagascar', 'Syrianair', 'Iran Air', 'Us Navy', 'Air Ceylon',
#        'Air Namibia', 'Zambian Airways', 'Westjet', 'Bahamasair',
#        'Channel Air Bridge', 'Buffalo Airways', 'Jetblue', 'Iron Annie',
#        'Panegra', 'Ansett Express', 'Fiji Airways', 'Avianca Brazil',
#        'Dan Air', 'Hongkong Express', 'Air Koryo', 'Azul Linhas Aereas',
#        'Pba', 'Universal Airlines', 'Usair', 'Nokscoot', 'Fantasy Aetna',
#        'Silkair', 'Sands Casino', 'Mackey International', 'Mahan',
#        'Frontier Airlines', 'Vietnam Airlines', 'Brussels Airlines',
#        'Air Congo', 'Avianca Colombia', 'Comair', 'Air Transat',
#        'Trans Carribean Airways', 'Vasp', 'Indian Airforce',
#        'Allegiant Air', 'Gator Global Flying', 'Taesa', 'Tui Airlines',
#        'Piedmont', 'Royal Jordanian', 'Air Tahiti', 'Volaris',
#        'Western Airlines', 'Novair', 'Cathay Dragon',
#        'Pan American Grace Airway', 'Panair Do Brasil', 'Jettrain',
#        'Icelandair', 'Latam', 'Silkway Airlines', 'Royal Australian Af',
#        'Air America', 'Utair', 'Trump', 'Rossiya', 'Ozark Airlines',
#        'Raaf', 'United Express', 'Allegheny Airlines', 'Sf Airlines',
#        'Air Caraibes', 'Aerocondor', 'Sun Country', 'Finlantic',
#        'Peoplexpress', 'Wow Air', 'Patriots', 'Aero California',
#        'Air Florida', 'Ukranian Airforce', 'Hongkong Airlines',
#        'Ariana Afghan', 'Air Greenland', 'Ukraine International',
#        'Astraeus', 'Spanair', 'Government Of Brunei', 'Air Zimbabwe',
#        'Air Rhodesia', 'Liat', 'Sukhoi Design Bureau', 'Indian Navy',
#        'Hi Fly', 'Royal Thai Air Force', 'Lam Mozambique',
#        'Thomas Cook Airlines', 'Trans Global Airlines', 'Capitol Airways',
#        'Flydubai', 'Real Transportes Aereos', 'Russian Air Force',
#        'Sun Dor', 'Saudi Arabian Government', 'Air Cote D Ivoire',
#        'Avensa', 'Kazakhstan Airforce', 'Japan Sdf', 'Hungarian Airforce',
#        'Slovakia Airforce', 'Venezuelan Airforce', 'Tarom', 'Private',
#        'Royal Nepal Airlines', 'Aerovias Q', 'Air Holland', 'Abx Air',
#        'Republic Of Korea Airforc', 'Polet Aviakompania', 'Eastern',
#        'South African Airforce', 'Ltu', 'Swiss Air', 'Lockheed'],
#       dtype=object)

# %%
airlinegrp.head()
# Out:
#                  total
# AIRLINE
# A-NET                1
# ABX AIR              1
# ADRIA                3
# AER LINGUS          29
# AERO CALIFORNIA      3

# %%
ai_df.describe()
# Out:
#                 ID       PRICE    SHIPPING         TAX
# count   191.000000  191.000000  191.000000  191.000000
# mean   2919.607330   41.326283    2.504712    0.020942
# std    3048.492176   27.496867    4.946391    0.204119
# min       2.000000    0.000000    0.000000    0.000000
# 25%     204.500000   27.725000    0.000000    0.000000
# 50%    1041.000000   32.950000    0.000000    0.000000
# 75%    6524.500000   40.225000    1.830000    0.000000
# max    8348.000000  137.000000   36.510000    2.000000

# %%
# configure elasticsearch

# %%
#exportdf.describe()

# %%
#import pyes
#es1=pyes.ES()
#exportdf["no_index"] = [x+1 for x in range(len(exportdf["ID"]))]
#tmp = exportdf.to_json(orient = "records")
# Load each record into json format before bulk
#df_json= json.loads(tmp)
#print(df_json[0])
# Create an index into elastic search. If we need to create a mapping, we ought to do it here
#index_name = 'cars'
#type_name = 'record'

# Bulk index
#for doc in df_json:
    #es1.index(doc, index_name, type_name,id=doc['no_index'])

# %%
INDEX="aircraft"
TYPE= "models"
#res = es.search(index=INDEX, body={"query":  {"match": {"REGISTRATION": "VR-HOA"}}})
res = es.search(index=INDEX, body={"query":  {"match_phrase": {"REGISTRATION": "VR-HOA"}}})
print('f{} documents found',res['hits']['total'])
for doc in res['hits']['hits']:
    #print(doc)
    print(doc['_id'], doc['_source'])
# Out:
# f{} documents found {'value': 5, 'relation': 'eq'}
# UOMVdG0BY_i7fwTTD6ZS {'ID': 1073, 'MODEL_NO': 'WID13288', 'DIMAID': None, 'WID': '13288', 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'Blue Box Cathay Pacific L-1011-100 1:400 - NA - ID#13288; 1980s  Colors. With  Chrome  Belly.VR-HOA', 'SIZE': '1:400', 'PRICE': 58.01, 'SHIPPING': 11.0, 'TAX': 0.0, 'COMPANY': 'BLUE BOX', 'ORDEREDFROM': 'ebay:kiet747', 'DATEOFORDER': 1334016000000, 'HangarClub': False, 'PictureID': 1176.0}
# ceMVdG0BY_i7fwTTD65W {'ID': 3743, 'MODEL_NO': 'BBOX101102', 'DIMAID': None, 'WID': '33578', 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'Blue Box Cathay Pacific L-1011-100 1:200 - BBOX101102 - ID#33578; 1980s  Colors.VR-HOA', 'SIZE': '1:200', 'PRICE': 97.0, 'SHIPPING': 0.0, 'TAX': 0.0, 'COMPANY': 'BLUE BOX', 'ORDEREDFROM': 'WAFFLECOLLECTIBLES', 'DATEOFORDER': 1346976000000, 'HangarClub': False, 'PictureID': 3706.0}
# jeMVdG0BY_i7fwTTD7xc {'ID': 7959, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 35.0, 'SHIPPING': 0.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'WAFFLECOLLECTIBLES', 'DATEOFORDER': 1538870400000, 'HangarClub': False, 'PictureID': 9791.0}
# m-MVdG0BY_i7fwTTD7xc {'ID': 7973, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 39.99, 'SHIPPING': 6.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'EBAY:JIMMY', 'DATEOFORDER': 1538784000000, 'HangarClub': False, 'PictureID': 9791.0}
# nOMVdG0BY_i7fwTTD7xc {'ID': 7974, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 39.99, 'SHIPPING': 6.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'EBAY:JIMMY', 'DATEOFORDER': 1538784000000, 'HangarClub': False, 'PictureID': 9791.0}

# %%
exportdf["month"]=exportdf["DATEOFORDER"].dt.month
exportdf["year"]=exportdf["DATEOFORDER"].dt.year
exportdf.head()
# Out:
#    ID  MODEL_NO  DIMAID    WID        AIRLINE AIRCRAFT_TYPE REGISTRATION  \
# 0   2  AC18022B     NaN   3873      AIR INDIA      B707-400       VT-DJI
# 1   3  HE502238     NaN  12793     KINGFISHER      A320-200       VT-KFA
# 2   7  DRW55934     NaN  13473  QATAR AIRWAYS      A330-200       A7-ACG
# 3  11    MP5805     NaN  17047      LUFTHANSA      A340-600           NA
# 4  12   AC4XEAJ     NaN  15977          EL AL    B767-300ER       4X-EAJ
#
#                                          DESCRIPTION   SIZE   PRICE  SHIPPING  \
# 0  Aeroclassics Air India B 707-437 1:400 - AC180...  1:400  122.00      20.0
# 1  Herpa Kingfisher Airlines A320-232 1:500 - 502...  1:500   26.00       3.0
# 2  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400   20.95       0.4
# 3  Model Power Lufthansa A340-642 1:500 - 5805 - ...  1:500   14.95       0.4
# 4  Aeroclassics El Al B 767-330ER 1:400 - AC4XEAJ...  1:400   15.00       1.0
#
#    TAX       COMPANY       ORDEREDFROM DATEOFORDER  HangarClub  PictureID  \
# 0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06       False        2.0
# 1  0.0         HERPA              DAC:  2011-02-06       False        3.0
# 2  0.0  DRAGON WINGS      3000toys.com  2011-02-04       False        6.0
# 3  0.0   MODEL POWER      3000TOYS.COM  2011-02-04       False       10.0
# 4  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02       False       12.0
#
#    month  year
# 0      2  2011
# 1      2  2011
# 2      2  2011
# 3      2  2011
# 4      1  2011

# %%
exportdf["netprice"]=exportdf["PRICE"]+exportdf["SHIPPING"]+exportdf["TAX"]
purchasesumdf=exportdf.groupby(["year","month"]).agg({"netprice":"sum"})
purchasesumdf.tail(1)
# Out:
#             netprice
# year month
# 2019 9       1163.51

# %%
#solddf.head()

# %%
solddf.rename(columns={"Net Recd":"Tot_SP"})
solddf["Tot_CP"]=solddf['price']+solddf["shipping"]+solddf["tax"]
solddf["tot_efees"]=solddf['ListingFee']+solddf["EbayFee"]+solddf["PaypalFee"]+solddf["tax"]
solddf['shippingfees']=solddf['Shipping']+solddf["Insurance"]
#solddf.head()
solddf=solddf.reset_index()
solddf=solddf.groupby(['year','month'],as_index=False).agg({'Listing price':'sum','Net Recd':'sum','ListingFee':'sum'\
                        ,'EbayFee':'sum','PaypalFee':'sum','Insurance':'sum','Shipping':'sum','NetRecd':'sum','profit_loss':'sum'})
#,'EbayFee','PaypalFee','Insurance','Shipping','NetRecd','profit_loss'

solddf.to_csv("E:\Practice\Aircraft\soldgraphs\sold.csv")
solddf.to_csv("E:\Practice\Aircraft\soldgraphs\sold.csv")
solddf.to_json("E:\Practice\Aircraft\soldgraphs\sold.csv",orient='records')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-3f83e9cb42a8> in <module>
#       9 #,'EbayFee','PaypalFee','Insurance','Shipping','NetRecd','profit_loss'
#      10
# ---> 11 solddf.to_csv("E:\Practice\Aircraft\soldgraphs\sold.csv")
#      12 solddf.to_csv("E:\Practice\Aircraft\soldgraphs\sold.csv")
#      13 solddf.to_json("E:\Practice\Aircraft\soldgraphs\sold.csv",orient='records')
#
# ~\AppData\Local\conda\conda\envs\Pythondata\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
#    1747         if path_or_buf is None:
#
# ~\AppData\Local\conda\conda\envs\Pythondata\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     154             f, handles = _get_handle(self.path_or_buf, self.mode,
#     155                                      encoding=encoding,
# --> 156                                      compression=self.compression)
#     157             close = True
#     158
#
# ~\AppData\Local\conda\conda\envs\Pythondata\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     398         elif encoding:
#     399             # Python 3 and encoding
# --> 400             f = open(path_or_buf, mode, encoding=encoding)
#     401         elif is_text:
#     402             # Python 3 and no explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\Practice\\Aircraft\\soldgraphs\\sold.csv'

# %%
solddf.head()

# %%
solddf.head()
# Out:
#    year  month  Listing price  Net Recd  ListingFee  EbayFee  PaypalFee  \
# 0  2011     12          34.00     42.00        0.72     3.06       1.52
# 1  2012      1          95.00    112.85        0.00    10.16       3.88
# 2  2012      2          34.00     42.00        0.00     3.78       1.52
# 3  2012      3         135.38    211.12        0.00     0.00       8.84
# 4  2012      4         928.48   1236.18        0.00    76.07      49.48
#
#    Insurance  Shipping  NetRecd  profit_loss
# 0       1.80      5.34    29.56         2.06
# 1       4.15      6.22    88.44        72.88
# 2       1.85      3.28    31.57         5.47
# 3       6.05     58.18   138.05        21.31
# 4       8.95    250.94   850.74       191.26

# %%
    db=client['Aircraft']
    colmodels=db['models']
    colmodels2=db['models2']
#    def modelinvest():
    data={}
    cursor = colmodels.find() 
    #for rec in cursor[:2]:  #slicning in loop to show only two records
     #print (rec)
    aggpipeline =[{ "$group": {"_id": "$AIRLINE", "total": { "$sum": "$PRICE" },"myCount": { "$sum": 1 }}}]
    cursor1=colmodels.aggregate(aggpipeline)

    cursor1
    #for rec in cursor1:
     #   print(rec)
    #print(list(cursor1))    
    summarydf = pd.DataFrame(list(colmodels.aggregate(aggpipeline))).rename(columns={"_id":"Airline","myCount":"ModelCount"})
    data = { "airline":summarydf["Airline"].tolist(),
               "ModelCount":summarydf["ModelCount"].tolist(),
                "total":summarydf["total"].tolist(),
           }
    #print(data)
    test=summarydf.to_json()
    print(test)
    #return jsonify(data)

#investdf = modelinvest()
#investdf.head()
# Out:
# {"Airline":{"0":"REPUBLIC OF KOREA AIRFORC","1":"ABX AIR","2":"AIR HOLLAND","3":"AEROVIAS Q","4":"PRIVATE","5":"EASTERN","6":"VENEZUELAN AIRFORCE","7":"SLOVAKIA AIRFORCE","8":"KAZAKHSTAN AIRFORCE","9":"SAUDI ARABIAN GOVERNMENT","10":"JAPAN SDF","11":"SUN DOR","12":"THOMAS COOK","13":"REAL TRANSPORTES AEREOS","14":"CAPITOL AIRWAYS","15":"TRANS GLOBAL AIRLINES","16":"LAM MOZAMBIQUE","17":"ROYAL THAI AIR FORCE","18":"INDIAN NAVY","19":"SUKHOI DESIGN BUREAU","20":"LIAT","21":"AIR RHODESIA","22":"AIR ZIMBABWE","23":"SPANAIR","24":"AIR GREENLAND","25":"UKRANIAN AIRFORCE","26":"PATRIOTS","27":"AEROCONDOR","28":"UNITED EXPRESS","29":"RAAF","30":"FINLANTIC","31":"OZARK AIRLINES","32":"AERO CALIFORNIA","33":"UTAIR","34":"AIR AMERICA","35":"FLYDUBAI","36":"JETTRAIN","37":"PAN AMERICAN GRACE AIRWAY","38":"CATHAY DRAGON","39":"NOVAIR","40":"WESTERN AIRLINES","41":"VOLARIS","42":"ROYAL JORDANIAN","43":"PIEDMONT","44":"TUI AIRLINES","45":"SF AIRLINES","46":"GATOR GLOBAL FLYING","47":"INDIAN AIRFORCE","48":"TRANS CARRIBEAN AIRWAYS","49":"AIR TRANSAT","50":"BRUSSELS AIRLINES","51":"VIETNAM AIRLINES","52":"TRUMP","53":"MAHAN","54":"NOKSCOOT","55":"USAIR","56":"UNIVERSAL AIRLINES","57":"AZUL LINHAS AEREAS","58":"AIR KORYO","59":"PANEGRA","60":"JETBLUE","61":"WESTJET","62":"US NAVY","63":"IRAN AIR","64":"AIR MADAGASCAR","65":"RAF","66":"AVENSA","67":"BLANK","68":"RUSSIAN AIR FORCE","69":"NORWEGIAN","70":"THOMAS COOK AIRLINES","71":"TRANSASIA","72":"AMAKUSA","73":"A-NET","74":"RYUKYU AIR COMMUTER","75":"DOUGLAS AIRCRAFT COMPANY","76":"AVIANOVA","77":"DELTA CHICAGO & SOUTHERN","78":"AEROMEXICO","79":"INDIGO","80":"PANAIR DO BRASIL","81":"AEROPERU","82":"ZAMBIA AIRWAYS","83":"RUSSIAN AIRFORCE","84":"MALEV","85":"CRUZEIRO","86":"NOK AIR","87":"NLM","88":"ASTRAEUS","89":"AIR MAURITIUS","90":"NORTHWEST TERRITORIAL","91":"QUEBECAIR","92":"TRANSAMERICA","93":"QUBECAIR","94":"JETSTAR HONGKONG","95":"PEOPLEXPRESS","96":"JADE CARGO","97":"ARIANA AFGHAN","98":"ICELANDAIR","99":"AEROMARITIME","100":"AIR BRIDGE CARGO","101":"ANK","102":"JETSTAR JAPAN","103":"ETHIOPIAN AIRLINES","104":"BEA","105":"AIR WEST","106":"PACIFIC AIR","107":"LADECO","108":"SEABOARD WORLD","109":"AIRTRAN","110":"AUSTRALIAN AIR EXPRESS","111":"BRITISH CALEDONIAN","112":"IBERIA EXPRESS","113":"GOAIR","114":"OMAN AIR","115":"FIJI AIRWAYS","116":"EVERGREEN","117":"THAI AIRASIA","118":"CHANNEL AIR BRIDGE","119":"AIR AUSTRALIA","120":"AMERICAN EAGLE","121":"WHITE","122":"TAAG","123":"FREEDOM AIR","124":"CONVIASA","125":"ANTONOV DESIGN BUREAU","126":"TNT","127":"BUFFALO AIRWAYS","128":"CASINO EXPRESS","129":"AIR NAMIBIA","130":"MALAYSIAN\/AIR INTER","131":"AEROSPATIALE","132":"AIR CONGO","133":"KUZU AIRLINES","134":"DRAX AIR","135":"SHANGHAI AIRLINES","136":"MSA","137":"ALLEGIANT AIR","138":"LANICA","139":"COLUMBIA AIRLINES","140":"CHINA NORTHERN","141":"LA DODGERS","142":"DHL","143":"KENYA AIRWAYS","144":"UTA","145":"CAAC","146":"MARTINAIR HOLLAND","147":"ROYAL BRUNEI","148":"VIRGIN NIGERIA","149":"INTERFLUG","150":"ALOHA AIRLINES","151":"MYAIR","152":"SUN COUNTRY","153":"HAPAG LLOYD","154":"ZAMBIAN AIRWAYS","155":"ROYAL AIR FORCE","156":"SRILANKAN","157":"ALIA","158":"USAF","159":"AMERICAN INTER ISLAND","160":"EDELWEISS","161":"MEA","162":"CHINA SOUTHERN","163":"BRITISH ASIA AIRWAYS","164":"EAST LINE AIRLINES","165":"DEER AIR","166":"WORLD AIRWAYS","167":"REPUBLIC AIRLINES","168":"MANDALA AIRLINES","169":"VIRGIN AUSTRALIA","170":"GRAND CHINA EXPRESS","171":"EASTERN AIRLINES","172":"SURINAM AIRWAYS","173":"DAS AIR CARGO","174":"UZBEKISTAN AIRWAYS","175":"AMIRI FLIGHT","176":"AIR EUROPA","177":"STARFLYER","178":"TAA","179":"WEST AIR","180":"VIRGIN SUN","181":"ROYAL AIR MAROC","182":"VIRGIN AMERICA","183":"NAL","184":"SOVIET AIR FORCE","185":"AUSTRALIAN","186":"AVIANCA COLOMBIA","187":"ATLANTIC AIRLINES","188":"KUNPEN","189":"JAS","190":"VIASA","191":"TIGER AIRWAYS","192":"IRON ANNIE","193":"HINDUJA CARGO","194":"CEBU PACIFIC","195":"MASWINGS","196":"EASYJET","197":"US AIRWAYS","198":"AIR NIUGI ...

# %%
cursor = colmodels.find({"AIRLINE":"AIR INDIA"}) 
for rec in cursor[:2]:  #slicning in loop to show only two records
         print (rec)
cursor = colmodels.find({"AIRLINE":"AIR INDIA"}, { "AIRLINE": 1, "AIRCRAFT_TYPE": 1, "REGISTRATION": 1,"_id":0 })
for rec in cursor[:2]:  #slicning in loop to show only two records
         print (rec)
print("++++++++++++++++++")
cursor = colmodels.find({"REGISTRATION":"VT-DJI"}, { "AIRLINE": 1, "AIRCRAFT_TYPE": 1, "REGISTRATION": 1,"_id":0 })
for rec in cursor:  #slicning in loop to show only two records
         print (rec)
# Out:
# {'_id': ObjectId('5d6e8a88d16abd3e34cc2443'), 'ID': 2, 'MODEL_NO': 'AC18022B', 'DIMAID': nan, 'WID': '3873', 'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI', 'DESCRIPTION': 'Aeroclassics Air India B 707-437 1:400 - AC18022B - ID#3873; 1960s - Delivery  Colors. Named  Nanda Devi .VT-DJI', 'SIZE': '1:400', 'PRICE': 122.0, 'SHIPPING': 20.0, 'TAX': 0.0, 'COMPANY': 'AEROCLASSICS', 'ORDEREDFROM': 'EBAY:marketa2218', 'DATEOFORDER': datetime.datetime(2011, 2, 6, 0, 0), 'HangarClub': False, 'PictureID': 2.0}
# {'_id': ObjectId('5d6e8a88d16abd3e34cc2452'), 'ID': 32, 'MODEL_NO': 'IF743003', 'DIMAID': nan, 'WID': '21375', 'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B747-300', 'REGISTRATION': 'VT-EPW', 'DESCRIPTION': 'Inflight200 Air India B 747-337SCD 1:200 - IF743003; 1990s  Colors. With Rolling Gears;VT-EPW', 'SIZE': '1:200', 'PRICE': 90.0, 'SHIPPING': 4.0, 'TAX': 0.0, 'COMPANY': 'INFLIGHT200', 'ORDEREDFROM': 'EBAY:JOHANCHAN2004', 'DATEOFORDER': datetime.datetime(2011, 1, 31, 0, 0), 'HangarClub': False, 'PictureID': 32.0}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B747-300', 'REGISTRATION': 'VT-EPW'}
# ++++++++++++++++++
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
