# %%
import sys
import pandas as pd
import pyodbc as pyodbc
from sqlalchemy.dialects.mssql import pymssql
import pymssql
import pymongo
import csv
import json
from pymongo import MongoClient
from flask import Flask, jsonify, render_template
client = MongoClient()
client = MongoClient('localhost', 27017)
#mongodb+srv://arinmuk:amarji123!@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority
cloudstr='mongodb+srv://arinmuk:amarji123!@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority'
cloudclient = MongoClient(cloudstr)
#import mysql as mysql
# Out:
# C:\Users\arin_\.conda\envs\pythondata\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   """

# %%
#servername='LAPTOP-HIB8VNLH'
servername='zbook'
username='arindam'
#pwd=input(" enter password : ")
pwd="Airbusa350xwb"
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host': 'localhost', 'port': 9200}])
es
# Out:
# <Elasticsearch([{'host': 'localhost', 'port': 9200}])>

# %%
def sqlread():
    conn = pymssql.connect(server=servername, user=username, password=pwd, database='aircraft') 
    cursor = conn.cursor()
    qry='SELECT * from aircraft'
    salesmasterqry='select ID, MODEL_NO, DIMAID, WID, AIRLINE, AIRCRAFT_TYPE, REGISTRATION, DESCRIPTION, SIZE, PRICE, SHIPPING, TAX, COMPANY, ORDEREDFROM, DATEOFORDER,  HangarClub,  PictureID from aircraftsold'
    salesqry='select s.*,a.price,a.shipping,a.tax from solddetails s inner join aircraftsold a on s.aircraftid=a.id '
    cursor.execute('SELECT * from aircraft')
    cursor.execute(salesqry)
    row = cursor.fetchone()  
    #while row:  
            #print(row)
            #row = cursor.fetchone()  
    sqldf=pd.read_sql(qry,conn)
    solddf=pd.read_sql(salesqry,conn)
    modelsolddf=pd.read_sql(salesmasterqry,conn)
    sqldf.head()
    return sqldf,solddf,modelsolddf
#mongodb+srv://arinmuk:amarji123!@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority

# %%
sqldf,solddf,modelsolddf = sqlread()
solddf.head()
solddf["profit_loss"]=solddf["NetRecd"]-(solddf["price"]+solddf["shipping"]+solddf["tax"])
solddf["Sale_Date"]=pd.to_datetime(solddf["SaleDate"])
solddf["month"]=solddf['SaleDate'].dt.month
solddf["year"]=solddf['SaleDate'].dt.year
solddf.head()
#solddf.set_index("SaleDate",inplace=True)
solddf.head()
sqldf.columns
calcdf = sqldf.drop(['DIMAID', 'WID','DESCRIPTION', 'PICTURE', 'Picture2',
       'Picture3', 'Rare', 'HangarClub', 'MarketValue', 'PictureID'],axis =1)
exportdf=sqldf.drop(['PICTURE', 'Picture2',
       'Picture3', 'Rare', 'MarketValue'], axis =1)
filename="E:/aircraft_phase_1/db/air.csv"
exportdf.to_csv(filename,index=None,header=False,encoding='utf-8')
modelsolddf.head()
# Out:
#    ID      MODEL_NO  DIMAID    WID             AIRLINE AIRCRAFT_TYPE  \
# 0   1  BB5-2002-26A     0.0   3694  SINGAPORE AIRLINES      B747-300
# 1   2      HE519892     0.0   2452             AIRPORT   AIRPORT:ACC
# 2   4      HE507998     NaN  13856       QATAR AIRWAYS      A330-300
# 3   5      HE507523     NaN  12826       QATAR AIRWAYS      A330-300
# 4   6      DRW55934     0.0  13473       QATAR AIRWAYS      A330-200
#
#   REGISTRATION                                        DESCRIPTION   SIZE  \
# 0       9V-SKN  BigBird Singapore Airlines B 747-312 1:500 - B...  1:500
# 1  ACCESSORIES            HERPA AIRPORT ACCESSORIES X 519892 cars  1:500
# 2       A7-AEG  Herpa Qatar Airways A330-302 1:500 - 507998 - ...  1:500
# 3       A7-AED  Herpa Qatar Airways A330-302 1:500 - 507523 - ...  1:500
# 4       A7-ACG  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400
#
#    PRICE  SHIPPING  TAX       COMPANY              ORDEREDFROM DATEOFORDER  \
# 0  27.00       5.0  0.0       BIGBIRD  WWW.EBAY.COM:chrism8036  2011-02-02
# 1  25.00       8.0  0.0         HERPA                     EBAY  2011-02-13
# 2  37.00       8.0  0.0         HERPA        DAC andrews huber  2011-01-05
# 3  37.00       8.0  0.0         HERPA        DAC andrews huber  2011-01-05
# 4  20.95       0.4  0.0  DRAGON WINGS             3000toys.com  2011-02-04
#
#    HangarClub  PictureID
# 0       False        0.0
# 1       False        0.0
# 2       False        4.0
# 3       False        0.0
# 4       False        0.0

# %%
def mongocloud(exportdf,slddf,mssolddf):
    db=cloudclient['Aircraft']
    colmodelscloud=db['models']
    colmodels2cloud=db['models2']
    colsale2cloud=db['solddetails']
    colmssoldcloud=db['modelsold']
    cursor = colmodelscloud.find() 
#for record in cursor: 
    colmodelscloud.drop()
    colsale2cloud.drop()
    colmodels2cloud.drop()
    colmssoldcloud.drop()
    #records = json.loads(exportdf.to_json(orient='records'))
    #records = json.loads(exportdf.T.to_json()).values()
    #db.models.insert_many(records)
    #db.insert_many(df.to_dict('records'))
    db.models.insert_many(exportdf.to_dict('records'))
    db.models2.insert_many(exportdf.to_dict('records'))
    db.solddetails.insert_many(slddf.to_dict('records'))
    db.modelsold.insert_many(mssolddf.to_dict('records'))

# %%
mongocloud(exportdf,solddf,modelsolddf)

# %%
def mongoR_I(exportdf,slddf,mssolddf):
    db=client['Aircraft']
    colmodels=db['models']
    colmodels2=db['models2']
    colsale=db['solddetails']
    colmssold=db['modelsold']
    cursor = colmodels.find() 
#for record in cursor: 
    colmodels.drop()
    colsale.drop()
    colmodels2.drop()
    colmssold.drop()
    #records = json.loads(exportdf.to_json(orient='records'))
    #records = json.loads(exportdf.T.to_json()).values()
    #db.models.insert_many(records)
    #db.insert_many(df.to_dict('records'))
    db.models.insert_many(exportdf.to_dict('records'))
    db.models2.insert_many(exportdf.to_dict('records'))
    db.solddetails.insert_many(slddf.to_dict('records'))
    db.modelsold.insert_many(mssolddf.to_dict('records'))

# %%
def elastic_update(exportdf,slddf,mssolddf):
    es.indices.delete(index='aircraft')
    es.indices.create(index='aircraft', ignore=400)
    es.indices.delete(index='solddetails')
    es.indices.create(index='solddetails', ignore=400)
    INDEX="aircraft"
    TYPE= "models"
    INDEX2="solddetails"
    TYPE2= "sales"
    INDEX3="modelsold"
    TYPE3= "modelsales"
    from bson import json_util

    def rec_to_actions(export1df,idxname,idxtype):
        #export1df["DATEOFORDER"]=export1df['DATEOFORDER'].dt.strftime('%Y-%m-%d')
        import json
        tmp = export1df.to_json(orient = "records")
        print(tmp)
    # Load each record into json format before bulk
        df_json= json.loads(tmp)
        for record in df_json: #export1df.to_dict(orient="records"):
            #print(record)
            yield ('{ "index" : { "_index" : "%s", "_type" : "%s" }}'% (idxname, idxtype))
            yield (json.dumps(record, default=str))

    #from elasticsearch import Elasticsearch
    #e = Elasticsearch() # no args, connect to localhost:9200
    if not es.indices.exists(INDEX):
        raise RuntimeError('index does not exists, use `curl -X PUT "localhost:9200/%s"` and try again'%INDEX)

    r = es.bulk(rec_to_actions(exportdf,INDEX,TYPE)) # return a dict
    r = es.bulk(rec_to_actions(slddf,INDEX2,TYPE2))
    r = es.bulk(rec_to_actions(mssolddf,INDEX3,TYPE3))
    print(not r["errors"])

# %%
mongoR_I(exportdf,solddf,modelsolddf)
elastic_update(exportdf,solddf,modelsolddf)
solddf.set_index("SaleDate",inplace=True)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [{"ID":1516,"AircraftID":1,"Listing price":59.0,"Net Recd":59.0,"SaleDate":1529193600000,"ListingFee":2.0,"EbayFee":5.4,"PaypalFee":2.9,"Shipping":4.38,"Insurance":2.7,"Buyer":"Ebay","NetRecd":41.62,"price":27.0,"shipping":5.0,"tax":0.0,"profit_loss":9.62,"Sale_Date":1529193600000,"month":6,"year":2018},{"ID":427,"AircraftID":2,"Listing price":52.0,"Net Recd":57.65,"SaleDate":1392422400000,"ListingFee":0.3,"EbayFee":5.77,"PaypalFee":2.55,"Shipping":1.93,"Insurance":2.6,"Buyer":"EBAY","NetRecd":44.5,"price":25.0,"shipping":8.0,"tax":0.0,"profit_loss":11.5,"Sale_Date":1392422400000,"month":2,"year":2014},{"ID":570,"AircraftID":4,"Listing price":77.0,"Net Recd":89.9,"SaleDate":1411344000000,"ListingFee":1.0,"EbayFee":8.09,"PaypalFee":3.81,"Shipping":3.11,"Insurance":1.7,"Buyer":"EBAY","NetRecd":72.19,"price":37.0,"shipping":8.0,"tax":0.0,"profit_loss":27.19,"Sale_Date":1411344000000,"month":9,"year":2014},{"ID":833,"AircraftID":5,"Listing price":93.0,"Net Recd":93.0,"SaleDate":1435449600000,"ListingFee":1.5,"EbayFee":8.37,"PaypalFee":3.93,"Shipping":3.44,"Insurance":1.7,"Buyer":"Ebay","NetRecd":74.06,"price":37.0,"shipping":8.0,"tax":0.0,"profit_loss":29.06,"Sale_Date":1435449600000,"month":6,"year":2015},{"ID":714,"AircraftID":6,"Listing price":53.0,"Net Recd":58.0,"SaleDate":1424563200000,"ListingFee":1.5,"EbayFee":5.2,"PaypalFee":2.0,"Shipping":2.19,"Insurance":1.2,"Buyer":"Ebay","NetRecd":45.91,"price":20.95,"shipping":0.4,"tax":0.0,"profit_loss":24.56,"Sale_Date":1424563200000,"month":2,"year":2015},{"ID":1539,"AircraftID":8,"Listing price":67.0,"Net Recd":79.95,"SaleDate":1534809600000,"ListingFee":2.0,"EbayFee":7.31,"PaypalFee":2.62,"Shipping":4.94,"Insurance":1.7,"Buyer":"Ebay","NetRecd":61.38,"price":20.95,"shipping":0.4,"tax":0.0,"profit_loss":40.03,"Sale_Date":1534809600000,"month":8,"year":2018},{"ID":716,"AircraftID":9,"Listing price":52.0,"Net Recd":57.0,"SaleDate":1424563200000,"ListingFee":1.5,"EbayFee":5.12,"PaypalFee":1.29,"Shipping":2.1,"Insurance":1.1,"Buyer":"Ebay","NetRecd":45.89,"price":20.95,"shipping":0.4,"tax":0.0,"profit_loss":24.54,"Sale_Date":1424563200000,"month":2,"year":2015},{"ID":1166,"AircraftID":10,"Listing price":18.0,"Net Recd":30.0,"SaleDate":1474588800000,"ListingFee":1.5,"EbayFee":2.7,"PaypalFee":1.17,"Shipping":3.5,"Insurance":1.7,"Buyer":"Ebay","NetRecd":19.43,"price":14.95,"shipping":0.4,"tax":0.0,"profit_loss":4.08,"Sale_Date":1474588800000,"month":9,"year":2016},{"ID":478,"AircraftID":11,"Listing price":60.0,"Net Recd":69.65,"SaleDate":1398643200000,"ListingFee":1.0,"EbayFee":6.97,"PaypalFee":3.02,"Shipping":2.59,"Insurance":1.7,"Buyer":"ebay","NetRecd":54.37,"price":21.99,"shipping":2.0,"tax":0.0,"profit_loss":30.38,"Sale_Date":1398643200000,"month":4,"year":2014},{"ID":437,"AircraftID":12,"Listing price":56.0,"Net Recd":61.65,"SaleDate":1393113600000,"ListingFee":1.0,"EbayFee":6.17,"PaypalFee":2.38,"Shipping":1.76,"Insurance":1.65,"Buyer":"EBAY","NetRecd":48.69,"price":22.0,"shipping":2.0,"tax":0.0,"profit_loss":24.69,"Sale_Date":1393113600000,"month":2,"year":2014},{"ID":317,"AircraftID":13,"Listing price":99.99,"Net Recd":113.34,"SaleDate":1378080000000,"ListingFee":0.6,"EbayFee":11.34,"PaypalFee":3.59,"Shipping":5.23,"Insurance":1.7,"Buyer":"EBAY","NetRecd":90.88,"price":25.0,"shipping":3.06,"tax":0.0,"profit_loss":62.82,"Sale_Date":1378080000000,"month":9,"year":2013},{"ID":382,"AircraftID":14,"Listing price":99.99,"Net Recd":113.34,"SaleDate":1385337600000,"ListingFee":1.0,"EbayFee":11.34,"PaypalFee":3.59,"Shipping":5.05,"Insurance":1.7,"Buyer":"ebay","NetRecd":90.66,"price":25.0,"shipping":3.06,"tax":0.0,"profit_loss":62.6,"Sale_Date":1385337600000,"month":11,"year":2013},{"ID":383,"AircraftID":15,"Listing price":99.99,"Net Recd":113.34,"SaleDate":1386201600000,"ListingFee":1.0,"EbayFee":11.34,"PaypalFee":3.59,"Shipping":6.51,"Insurance":1.7,"Buyer":"ebay","NetRecd":89.2,"price":25.0,"shipping":3.06,"tax":0.0,"profit_loss":61.14,"Sale_Date":1386201600000,"month":12,"year":2013 ...
# [{"ID":1,"MODEL_NO":"BB5-2002-26A","DIMAID":0.0,"WID":"3694","AIRLINE":"SINGAPORE AIRLINES","AIRCRAFT_TYPE":"B747-300","REGISTRATION":"9V-SKN","DESCRIPTION":"BigBird Singapore Airlines B 747-312 1:500 - BB5-2002-26A - ID#3694 ;\"1980s\" Colors. Named \"Big Top\".9V-SKN","SIZE":"1:500","PRICE":27.0,"SHIPPING":5.0,"TAX":0.0,"COMPANY":"BIGBIRD","ORDEREDFROM":"WWW.EBAY.COM:chrism8036","DATEOFORDER":1296604800000,"HangarClub":false,"PictureID":0.0},{"ID":2,"MODEL_NO":"HE519892","DIMAID":0.0,"WID":"2452","AIRLINE":"AIRPORT","AIRCRAFT_TYPE":"AIRPORT:ACC","REGISTRATION":"ACCESSORIES","DESCRIPTION":"HERPA AIRPORT ACCESSORIES X 519892 cars","SIZE":"1:500","PRICE":25.0,"SHIPPING":8.0,"TAX":0.0,"COMPANY":"HERPA","ORDEREDFROM":"EBAY","DATEOFORDER":1297555200000,"HangarClub":false,"PictureID":0.0},{"ID":4,"MODEL_NO":"HE507998","DIMAID":null,"WID":"13856","AIRLINE":"QATAR AIRWAYS","AIRCRAFT_TYPE":"A330-300","REGISTRATION":"A7-AEG","DESCRIPTION":"Herpa Qatar Airways A330-302 1:500 - 507998 - ID#13856;\"15th Asian Games - Red\" Colors. New Generation. Exclusive for Qatar Airways In-Flight Sales.A7-AEG","SIZE":"1:500","PRICE":37.0,"SHIPPING":8.0,"TAX":0.0,"COMPANY":"HERPA","ORDEREDFROM":"DAC andrews huber","DATEOFORDER":1294185600000,"HangarClub":false,"PictureID":4.0},{"ID":5,"MODEL_NO":"HE507523","DIMAID":null,"WID":"12826","AIRLINE":"QATAR AIRWAYS","AIRCRAFT_TYPE":"A330-300","REGISTRATION":"A7-AED","DESCRIPTION":"Herpa Qatar Airways A330-302 1:500 - 507523 - ID#12826;\"15th Asian Games - Doha 2004 - Orange\" Colors. New Generation. Exclusive for Qatar Airways Inflight Sales.A7-AED","SIZE":"1:500","PRICE":37.0,"SHIPPING":8.0,"TAX":0.0,"COMPANY":"HERPA","ORDEREDFROM":"DAC andrews huber","DATEOFORDER":1294185600000,"HangarClub":false,"PictureID":0.0},{"ID":6,"MODEL_NO":"DRW55934","DIMAID":0.0,"WID":"13473","AIRLINE":"QATAR AIRWAYS","AIRCRAFT_TYPE":"A330-200","REGISTRATION":"A7-ACG","DESCRIPTION":"Dragon Wings Qatar Airways A330-202 1:400 - 55934 - ID#13473 :\"Asian Games - Doha 2006 - Blue\" Colors. With Stand.  A7-ACG,PART OF 2 PLANE SET","SIZE":"1:400","PRICE":20.95,"SHIPPING":0.4,"TAX":0.0,"COMPANY":"DRAGON WINGS","ORDEREDFROM":"3000toys.com","DATEOFORDER":1296777600000,"HangarClub":false,"PictureID":0.0},{"ID":8,"MODEL_NO":"DRW55935","DIMAID":0.0,"WID":"13507","AIRLINE":"QATAR AIRWAYS","AIRCRAFT_TYPE":"A330-300","REGISTRATION":"A7-AEG","DESCRIPTION":"Dragon Wings Qatar Airways A330-302 1:400 - 55935 - ID#13507; 15th Asian Games Doha 2006 - Red  Colors. With Stand.A7-AEG","SIZE":"1:400","PRICE":20.95,"SHIPPING":0.4,"TAX":0.0,"COMPANY":"DRAGON WINGS","ORDEREDFROM":"3000toys.com","DATEOFORDER":1296777600000,"HangarClub":false,"PictureID":0.0},{"ID":9,"MODEL_NO":"DRW55935","DIMAID":0.0,"WID":"13507","AIRLINE":"QATAR AIRWAYS","AIRCRAFT_TYPE":"A330-300","REGISTRATION":"A7-AEG","DESCRIPTION":"Dragon Wings Qatar Airways A330-302 1:400 - 55935 - ID#13507;\"15th Asian Games Doha 2006 - Red\" Colors. With Stand.A7-AEG","SIZE":"1:400","PRICE":20.95,"SHIPPING":0.4,"TAX":0.0,"COMPANY":"DRAGON WINGS","ORDEREDFROM":"3000toys.com","DATEOFORDER":1296777600000,"HangarClub":false,"PictureID":0.0},{"ID":10,"MODEL_NO":"MP5805","DIMAID":0.0,"WID":"17047","AIRLINE":"LUFTHANSA","AIRCRAFT_TYPE":"A340-600","REGISTRATION":"NA","DESCRIPTION":"Model Power Lufthansa A340-642 1:500 - 5805 - ID#17047;\"1990s\" Colors. With \"Star Alliance\" Logo. With Stand.NA","SIZE":"1:500","PRICE":14.95,"SHIPPING":0.4,"TAX":0.0,"COMPANY":"MODEL POWER","ORDEREDFROM":"3000TOYS.COM","DATEOFORDER":1296777600000,"HangarClub":false,"PictureID":0.0},{"ID":11,"MODEL_NO":"HE519472","DIMAID":0.0,"WID":"5236","AIRLINE":"AIRPORT","AIRCRAFT_TYPE":"GSE","REGISTRATION":"ACCESSORIES","DESCRIPTION":"Herpa Airport Accessories Airport GSE 1:500 - 519472 - ID#5236 19 Pieces.","SIZE":"1:500","PRICE":21.99,"SHIPPING":2.0,"TAX":0.0,"COMPANY":"HERPA","ORDEREDFROM":"EBAY:SHARONDEALS","DATEOFORDER":1356912000000,"HangarClub":false,"PictureID":0.0},{"ID":12,"MODEL_NO":"HE519472","DIMAID":0.0,"WID":"5236","AIRLINE ...
# True

# %%
exportdf.head()
#exportdf['DATEOFORDER']=(exportdf['DATEOFORDER'])
exportdf.head()
# Out:
#    ID  MODEL_NO  DIMAID    WID        AIRLINE AIRCRAFT_TYPE REGISTRATION  \
# 0   2  AC18022B     NaN   3873      AIR INDIA      B707-400       VT-DJI
# 1   3  HE502238     0.0  12793     KINGFISHER      A320-200       VT-KFA
# 2   7  DRW55934     0.0  13473  QATAR AIRWAYS      A330-200       A7-ACG
# 3  11    MP5805     0.0  17047      LUFTHANSA      A340-600           NA
# 4  12   AC4XEAJ     NaN  15977          EL AL    B767-300ER       4X-EAJ
#
#                                          DESCRIPTION   SIZE   PRICE  SHIPPING  \
# 0  Aeroclassics Air India B 707-437 1:400 - AC180...  1:400  122.00      20.0
# 1  Herpa Kingfisher Airlines A320-232 1:500 - 502...  1:500   26.00       3.0
# 2  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400   20.95       0.4
# 3  Model Power Lufthansa A340-642 1:500 - 5805 - ...  1:500   14.95       0.4
# 4  Aeroclassics El Al B 767-330ER 1:400 - AC4XEAJ...  1:400   15.00       1.0
#
#    TAX       COMPANY       ORDEREDFROM DATEOFORDER  HangarClub  PictureID
# 0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06       False        2.0
# 1  0.0         HERPA              DAC:  2011-02-06       False        3.0
# 2  0.0  DRAGON WINGS      3000toys.com  2011-02-04       False        6.0
# 3  0.0   MODEL POWER      3000TOYS.COM  2011-02-04       False       10.0
# 4  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02       False       12.0

# %%
exportdf.columns
exportdf["DATEOFORDER"]=pd.to_datetime(exportdf['DATEOFORDER'])
exportdf["DATEOFORDER"].dtype
# Out:
# dtype('<M8[ns]')

# %%
#db.models2.insert_many(records)
calcdf.head()
# Out:
#    ID  MODEL_NO        AIRLINE AIRCRAFT_TYPE REGISTRATION   SIZE   PRICE  \
# 0   2  AC18022B      AIR INDIA      B707-400       VT-DJI  1:400  122.00
# 1   3  HE502238     KINGFISHER      A320-200       VT-KFA  1:500   26.00
# 2   7  DRW55934  QATAR AIRWAYS      A330-200       A7-ACG  1:400   20.95
# 3  11    MP5805      LUFTHANSA      A340-600           NA  1:500   14.95
# 4  12   AC4XEAJ          EL AL    B767-300ER       4X-EAJ  1:400   15.00
#
#    SHIPPING  TAX       COMPANY       ORDEREDFROM DATEOFORDER
# 0      20.0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06
# 1       3.0  0.0         HERPA              DAC:  2011-02-06
# 2       0.4  0.0  DRAGON WINGS      3000toys.com  2011-02-04
# 3       0.4  0.0   MODEL POWER      3000TOYS.COM  2011-02-04
# 4       1.0  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02

# %%
airlinegrp=calcdf.groupby(['AIRLINE']).ID.agg(['count'])
airlinegrp.head(5)
airlinegrp=airlinegrp.rename(columns={'count':"total"})

airlinegrp.head()
airlinetotal=calcdf.groupby(['SIZE']).agg({'PRICE':['sum'],'ID':'count'}).rename(columns={'sum':"cost"})
airlinetotal.head(14)
# Out:
#             PRICE    ID
#              cost count
# SIZE
# 1:100     1357.98    14
# 1:1000      58.00     2
# 1:130      255.00     3
# 1:144      420.25     5
# 1:150        0.00     1
# 1:160        0.00     1
# 1:187       10.00     1
# 1:200   168533.13  2312
# 1:250       54.99     7
# 1:300      373.67     9
# 1:400   162156.62  5113
# 1:500     3646.02   146
# 1:600       27.70     2
# 1:72      1417.73    28

# %%
ai_df=calcdf[calcdf["AIRLINE"]=='air india'.upper()]
ai_df.head()
# Out:
#     ID  MODEL_NO    AIRLINE AIRCRAFT_TYPE REGISTRATION   SIZE  PRICE  \
# 0    2  AC18022B  AIR INDIA      B707-400       VT-DJI  1:400  122.0
# 15  32  IF743003  AIR INDIA      B747-300       VT-EPW  1:200   90.0
# 16  33  IF743003  AIR INDIA      B747-300       VT-EPW  1:200   90.0
# 58  85   ACVTDVB  AIR INDIA      B707-300       VT-DVB  1:400   33.0
# 64  91  AC18022B  AIR INDIA      B707-400       VT-DJI  1:400   35.0
#
#     SHIPPING  TAX       COMPANY         ORDEREDFROM DATEOFORDER
# 0       20.0  0.0  AEROCLASSICS    EBAY:marketa2218  2011-02-06
# 15       4.0  0.0   INFLIGHT200  EBAY:JOHANCHAN2004  2011-01-31
# 16       4.0  0.0   INFLIGHT200  EBAY:JOHANCHAN2004  2011-01-31
# 58       5.0  0.0  AEROCLASSICS       www.ebay.com:  2010-12-28
# 64       2.0  0.0  AEROCLASSICS        dac:jr lopez  2011-02-17

# %%
solddf.sort_index(inplace=True)
solddf["profit_loss"].plot()

# %%
solddf.index
# Out:
# DatetimeIndex(['2011-12-31', '2012-01-12', '2012-01-28', '2012-01-28',
#                '2012-02-15', '2012-03-03', '2012-03-03', '2012-03-03',
#                '2012-03-12', '2012-04-03',
#                ...
#                '2020-01-29', '2020-01-30', '2020-02-02', '2020-02-02',
#                '2020-02-02', '2020-02-10', '2020-02-15', '2020-02-15',
#                '2020-02-15', '2020-02-16'],
#               dtype='datetime64[ns]', name='SaleDate', length=1748, freq=None)

# %%
solddf["profit_loss"].rolling(30).mean().plot()

# %%
calcdf["AIRLINE"]=calcdf['AIRLINE'].str.title()
list(set(calcdf['AIRLINE'].values.tolist()))
# Out:
# ['Avensa',
#  'Mexicana',
#  'Ghana Airways',
#  'Lauda Air',
#  'Austrian Airlines',
#  'Alia',
#  'Continental',
#  'Air West',
#  'Tat',
#  'Emirates',
#  'Shanghai Airlines',
#  'Sun Country',
#  'Air Tahiti',
#  'Pby Foundation',
#  'Ukraine International',
#  'Mexican Air Force',
#  'British Asia Airways',
#  'Novair',
#  'Jalways',
#  'Sabena',
#  'World Airways',
#  'Canadian Airlines',
#  'Compass Airlines',
#  'Edelweiss',
#  'Ryukyu Air Commuter',
#  'Avianova',
#  'Government Of Brunei',
#  'Atlantic Airlines',
#  'Virgin Atlantic',
#  'Lot',
#  'Syrianair',
#  'Alitalia',
#  'Northeast',
#  'Eastern Airlines',
#  'Binter Canarias',
#  'British Caledonian',
#  'Saha Air Lines',
#  'Nok Air',
#  'Australian Air Express',
#  'Air Canada',
#  'Ecuatoriana',
#  'Boac',
#  'Maswings',
#  'Air India Express',
#  'Indian Navy',
#  'Royal Australian Af',
#  'Air France',
#  'Transaero Airlines',
#  'Us Navy',
#  'Air America',
#  'Silkway Airlines',
#  'Caledonian Airways',
#  'Aerospatiale',
#  'Ansett Express',
#  'Goair',
#  'British Airtours',
#  'Hapag Lloyd',
#  'Dragonair',
#  'Sobelair',
#  'Biman Bangladesh',
#  'Lufthansa',
#  'Uta',
#  'Nasa',
#  'Virgin Nigeria Airways',
#  'Air Asia',
#  'Channel Air Bridge',
#  'Hinduja Cargo',
#  'Comair',
#  'Raf',
#  'Delta',
#  'Jetstar Asia',
#  'Flying Tigers',
#  'Etihad Airways',
#  'Northwest Territorial',
#  'Csa Czech Airlines',
#  'Royal Air Maroc',
#  'Standard Airways',
#  'Kuwait Airways',
#  'Royal Nepal Airlines',
#  'Monarch',
#  'Tui Airlines',
#  'Thomson Airways',
#  'Aerolineas Argentinas',
#  'American Eagle',
#  'Kingfisher',
#  'Shenzhen Airlines',
#  'Zas',
#  'Trans Canada Airlines',
#  'Air Rhodesia',
#  'Cp Air',
#  'Air Caraibes',
#  'Germainia',
#  'Nal',
#  'Westjet',
#  'Royal Brunei',
#  'Nigeria Airways',
#  'Virgin Blue',
#  'Malaysia Airlines',
#  'Virgin Australia',
#  'Kunpen',
#  'Evergreen',
#  'South African Airforce',
#  'Kazakhstan Airforce',
#  'Surinam Airways',
#  'Fantasy Aetna',
#  'Luxair',
#  'Fiji Airways',
#  'Cargolux',
#  'Norwegian',
#  'Kmv',
#  'Kenya Airways',
#  'Bahamasair',
#  'Sas',
#  'Transbrasil',
#  'Overseas National',
#  'Pacific Blue',
#  'Wardair',
#  'China Southern',
#  'Thai Airasia',
#  'Oceanair',
#  'Western Pacific',
#  'Olympic',
#  'Das Air Cargo',
#  'Jetstar',
#  'Fedex',
#  'Singapore Airlines',
#  'Air Seychelles',
#  'Seaboard World',
#  'Psa',
#  'Malev',
#  'Cathay Dragon',
#  'Astraeus',
#  'Martinair Holland',
#  'Ups',
#  'United Express',
#  'Finlantic',
#  'Delta Express',
#  'Airbus',
#  'Tap Air Portugal',
#  'Tiger Airways Australia',
#  'Air Greenland',
#  'British Airways',
#  'Ariana Afghan',
#  'Trans Carribean Airways',
#  'Tam',
#  'Srilankan',
#  'Allegiant Air',
#  'Air Hongkong',
#  'Pelita Air',
#  'Japan Sdf',
#  'Horizon Air',
#  'Sands Casino',
#  'Nokscoot',
#  'Ltu',
#  'Skyeurope',
#  'Transasia',
#  'China Northern',
#  'Taca',
#  'Crossair',
#  'Gulf Air',
#  'Thai Airways',
#  'Iaf',
#  'Hainan Airlines',
#  'Avianca Colombia',
#  'Civil Air Transport',
#  'South African',
#  'Northwest Airlink',
#  'Ata',
#  'Song',
#  'Indian Airforce',
#  'Korean Air',
#  'Usaf',
#  'Pluna',
#  'Easyjet',
#  'Transamerica',
#  'Ethiopian Airlines',
#  'Air Berlin',
#  'Turkish Airlines',
#  'Viasa',
#  'Northwest',
#  'Israir',
#  'Gator Global Flying',
#  'Indian Airlines',
#  'New York Air',
#  'Flydubai',
#  'East Line Airlines',
#  'Jas',
#  'Trans Global Airlines',
#  'Air Niugini',
#  'Garuda Indonesia',
#  'European Aircharter',
#  'Quebecair',
#  'Eva Air',
#  'Air Uk',
#  'Kalitta Air',
#  'Russian Airforce',
#  'A-Net',
#  'American Airlines',
#  'Atlas Air',
#  'Pba',
#  'Air Caraïbes Atlantique',
#  'Capitol Airways',
#  'Lockheed',
#  'Virgin Sun',
#  'Tower Air',
#  'Indigo',
#  'Utair',
#  'Taesa',
#  'Peoplexpress',
#  'Lan Chile',
#  'Vasp',
#  'Virgin America',
#  'Caledonian',
#  'Jetstar Japan',
#  'Mandala Airlines',
#  'Dhl',
#  'Scanair',
#  'Iran Air',
#  'Sf Airlines',
#  'Aeronaves De Mexico',
#  'Trump',
#  'Spirit Airlines',
#  'Lanica',
#  'Antonov Design Bureau',
#  'Ladeco',
#  'Bea',
#  'Venezuelan Airforce',
#  'Air Madagascar',
#  'Slovakia Airforce',
#  'Douglas Aircraft Company',
#  'Air Florida',
#  'Sky Airlines',
#  'Caac',
#  'China Eastern',
#  'Private',
#  'Taa',
#  'Playboy',
#  'Afriqiyah Airways',
#  'Tunis Air',
#  'Hawaiian Airlines',
#  'Thomsonfly',
#  'Merpati Nusantara',
#  'Republic Airlines',
#  'Air Jamaica',
#  'Qatar',
#  'Air China',
#  'Tibet Airlines',
#  'Rossiya',
#  'Luftwaffe',
#  'Sichuan Airlines',
#  'Heavylift',
#  'Aerosur',
#  'American Inter Island',
#  'Arrow Air',
#  'Australian',
#  'Brussels Airlines',
#  'Air Holland',
#  'Sunwing',
#  'Air Cote D Ivoire',
#  'Jat',
#  'Sudan Airways',
#  'Amiri Flight',
#  'Interflug',
#  'Myair',
#  'Aerovias Q',
#  'Condor',
#  'Jettrain',
#  'Aer Lingus',
#  'Iceland Air',
#  'Aeromaritime',
#  'Klm',
#  'Aeroperu',
#  'Jaz',
#  'Virgin Galactic',
#  'Nlm',
#  'Buffalo Airways',
#  'Gulf Traveller',
#  'Aeroflot',
#  'Philippine Airlines',
#  'Pia',
#  'Starflyer',
#  'Air Austral',
#  'Air Congo',
#  'Virgin Samoa',
#  'La Dodgers',
#  'Air Koryo',
#  'Air Liberte',
#  'Usair',
#  'British Eagle',
#  'Hungarian Airforce',
#  'Casino Express',
#  'Air Namibia',
#  'Corsair',
#  'Royal Jordan',
#  'National Airlines',
#  'Cathay Pacific',
#  'Ana',
#  'Iberia',
#  'Varig',
#  'Us Airways',
#  'Real Transportes Aereos',
#  'Republic Of Korea Airforc',
#  'Hi Fly',
#  'Jal Express',
#  'Hokkaido International',
#  'Ciskei International',
#  'Air California',
#  'Royal Thai Air Force',
#  'Pb Air',
#  'Swissair',
#  'V Australia',
#  'Mackey International',
#  'Dan Air',
#  'Polet Aviakompania',
#  'El Al',
#  'Air New Zealand',
#  'Northwest Orient',
#  'Zambia Airways',
#  'Mahan',
#  'Avianca Brazil',
#  'Dachser',
#  'Ansett Australia',
#  'Air Europe',
#  'Egypt Air',
#  'Nca',
#  'China Airlines',
#  'Universal Airlines',
#  'Panegra',
#  'Alaska Airlines',
#  'West Air',
#  'Vietnam Airlines',
#  'Northeastern',
#  'Panam',
#  'Western Airlines',
#  'Global Aviation Leasing',
#  'Iron Annie',
#  'Virgin Nigeria',
#  'Spanair',
#  'Aloha Airlines',
#  'Freedom Air',
#  'Grand China Express',
#  'Air Europa',
#  'Lam Mozambique',
#  'Piedmont',
#  'Air Charter',
#  'White',
#  'Spicejet',
#  'Zambian Airways',
#  'Oman Air',
#  'Australia Asia Airlines',
#  'Tnt',
#  'Aerocondor',
#  'Hongkong Airlines',
#  'Air Atlantic',
#  'Sun Dor',
#  'Asiana Airlines',
#  'Mas',
#  'Air Nippon',
#  'Ati',
#  'Abx Air',
#  'Blank',
#  'Air Zimbabwe',
#  'Ukranian Airforce',
#  'Qantaslink',
#  'Qubecair',
#  'Bangkok Airways',
#  'Pan American Grace Airway',
#  'Nordair',
#  'Tuifly.Com',
#  'Atlant-Soyuz Airlines',
#  'Ryanair',
#  'Boeing',
#  'Air Australia',
#  'United',
#  'Msa',
#  'Express.Net',
#  'Conviasa',
#  'Jade Cargo',
#  'Silkair',
#  'Jal',
#  'Slovak Airlines',
#  'Air India',
#  'Adria',
#  'Pacific Air',
#  'Amakusa',
#  'Cebu Pacific',
#  'Deer Air',
#  'Qatar Airways',
#  'Jet Airways',
#  'Fantasy',
#  'Finnair',
#  'Faucett Peru',
#  'Cruzeiro',
#  'Vnukovo Airlines',
#  'Airtran',
#  'Ozark Airlines',
#  'Bmi',
#  'Saudi Arabian',
#  'Latam',
#  'Huges Airwest',
#  'Jetstar Hongkong',
#  'Kuzu Airlines',
#  'Thomas Cook Airlines',
#  'Sukhoi Design Bureau',
#  'Qantas',
#  'Southwest',
#  'Royal Jordanian',
#  'Aeromexico',
#  'Air Transat',
#  'Jaa',
#  'Liat',
#  'Air Inter',
#  'Air Tanzania',
#  'Columbia Airlines',
#  'Japan Asia Airways',
#  'Volaris',
#  'Britannia Airways',
#  'Skymark Airlines',
#  'Air Afrique',
#  'Panair Do Brasil',
#  'Patriots',
#  'Delta Chicago & Southern',
#  'Malaysian/Air Inter',
#  'Royal Aviation',
#  'Carcon',
#  'Taag',
#  'Hongkong Express',
#  'Orient Thai',
#  'Mea',
#  'Braniff',
#  'Aero California',
#  'Air Pacific',
#  'Saudi Arabian Government',
#  'Turkmenistan Airlines',
#  'Megantara',
#  'Scoot',
#  'British Midland',
#  'Phuket Airlines',
#  'Ank',
#  'Icelandair',
#  'Tarom',
#  'Canadian Pacific',
#  'Twa',
#  'Royal Air Force',
#  'Skywest Airlines',
#  'Bwia',
#  'Air Mauritius',
#  'Azul Linhas Aereas',
#  'Mandarin',
#  'Air Ceylon',
#  'Drax Air',
#  'K Mile',
#  'Air Zaire',
#  'Air Bridge Cargo',
#  'Uat',
#  'Ansett New Zealand',
#  'Frontier Airlines',
#  'Cubana',
#  'Polynesian Airlines',
#  'America West',
#  'Mcdonnell Douglas',
#  'Air 2000',
#  'German Cargo',
#  'Iberia Express',
#  'Tiger Airways',
#  'Allegheny Airlines',
#  'Iraqi Airways',
#  'Wow Air',
#  'Laker Airways',
#  'Air Pullmantur',
#  'Soviet Air Force',
#  'Jetblue',
#  'Raaf',
#  'Uzbekistan Airways']

# %%
calcdf["AIRLINE"].unique()
# Out:
# array(['Air India', 'Kingfisher', 'Qatar Airways', 'Lufthansa', 'El Al',
#        'Ana', 'Panam', 'Canadian Pacific', 'Garuda Indonesia',
#        'American Airlines', 'Qantas', 'Jal', 'Cp Air', 'Air New Zealand',
#        'Air Europe', 'Klm', 'Air France', 'Thai Airways', 'Air Canada',
#        'Northwest', 'British Airways', 'Emirates', 'Austrian Airlines',
#        'Air China', 'Airbus', 'South African', 'Continental',
#        'Qantaslink', 'Cathay Pacific', 'National Airlines',
#        'Singapore Airlines', 'Iberia', 'Virgin Atlantic',
#        'Transaero Airlines', 'Jet Airways', 'Iaf', 'Air India Express',
#        'Etihad Airways', 'Malaysia Airlines', 'Carcon', 'Air Berlin',
#        'Egypt Air', 'Turkish Airlines', 'Flying Tigers', 'Boeing',
#        'Mandarin', 'Fedex', 'Spicejet', 'Air Liberte', 'Pia', 'United',
#        'Jalways', 'Sabena', 'Indian Airlines', 'Tap Air Portugal',
#        'Gulf Air', 'Gulf Traveller', 'Virgin Blue', 'Alaska Airlines',
#        'Twa', 'Varig', 'Aerolineas Argentinas', 'Song', 'Cubana', 'Delta',
#        'Eva Air', 'Jat', 'Air Pacific', 'Germainia', 'Swissair',
#        'Braniff', 'Condor', 'Dachser', 'Luftwaffe', 'Ghana Airways',
#        'Jaa', 'K Mile', 'Aeronaves De Mexico', 'Air 2000', 'Korean Air',
#        'Alitalia', 'America West', 'Ata', 'Finnair', 'Hawaiian Airlines',
#        'Hokkaido International', 'Luxair', 'Overseas National',
#        'Royal Aviation', 'Ups', 'Australia Asia Airlines',
#        'Virgin Nigeria Airways', 'Lan Chile', 'Lauda Air',
#        'China Airlines', 'Asiana Airlines', 'Oceanair', 'Mas', 'Scanair',
#        'Afriqiyah Airways', 'V Australia', 'Bwia', 'China Eastern',
#        'Air Caraïbes Atlantique', 'Lot', 'Air Asia', 'Aeroflot',
#        'Skymark Airlines', 'Biman Bangladesh', 'Atlas Air', 'Aer Lingus',
#        'Spirit Airlines', 'Northwest Orient', 'Western Pacific', 'Bmi',
#        'Binter Canarias', 'Southwest', 'Thomson Airways', 'Air Austral',
#        'Hainan Airlines', 'Olympic', 'Canadian Airlines',
#        'Ansett Australia', 'Kalitta Air', 'Sas', 'Aerosur',
#        'Japan Asia Airways', 'Israir', 'Northeast', 'Sobelair',
#        'Caledonian Airways', 'Air Hongkong', 'Air Uk', 'New York Air',
#        'Britannia Airways', 'Monarch', 'Sudan Airways', 'Jal Express',
#        'Polynesian Airlines', 'Bangkok Airways', 'German Cargo', 'Nasa',
#        'Sky Airlines', 'Skywest Airlines', 'Shenzhen Airlines',
#        'Sichuan Airlines', 'Air Charter', 'Air Niugini', 'Dragonair',
#        'Easyjet', 'Cebu Pacific', 'Hinduja Cargo', 'Megantara',
#        'Philippine Airlines', 'Air Seychelles', 'Air Tanzania',
#        'Tiger Airways', 'Tiger Airways Australia', 'Viasa',
#        'Air Pullmantur', 'Australian', 'Jetstar', 'Virgin America',
#        'Pacific Blue', 'Royal Air Maroc', 'Royal Jordan', 'Virgin Sun',
#        'Taa', 'Maswings', 'Nal', 'Starflyer', 'Air Europa',
#        'Avianca Colombia', 'Jas', 'Nca', 'Tam', 'Tuifly.Com',
#        'Amiri Flight', 'Pelita Air', 'Merpati Nusantara', 'Us Airways',
#        'Das Air Cargo', 'Csa Czech Airlines', 'Orient Thai',
#        'Eastern Airlines', 'Grand China Express', 'Air Inter',
#        'Virgin Australia', 'Mandala Airlines', 'Boac', 'Deer Air',
#        'West Air', 'British Asia Airways', 'Mea', 'Saudi Arabian',
#        'Edelweiss', 'Usaf', 'Alia', 'Srilankan', 'Corsair', 'Wardair',
#        'Fantasy', 'Uzbekistan Airways', 'China Southern', 'Myair',
#        'Playboy', 'Skyeurope', 'Aloha Airlines', 'Laker Airways',
#        'Interflug', 'Ciskei International', 'Martinair Holland', 'Caac',
#        'British Airtours', 'World Airways', 'Uta', 'Royal Brunei',
#        'Transbrasil', 'Crossair', 'Horizon Air', 'Kenya Airways',
#        'Hapag Lloyd', 'Surinam Airways', 'La Dodgers',
#        'European Aircharter', 'Air Afrique', 'Kuwait Airways',
#        'China Northern', 'Columbia Airlines', 'Air California', 'Lanica',
#        'Adria', 'Zas', 'Msa', 'Mexicana', 'Express.Net',
#        'Shanghai Airlines', 'Kuzu Airlines', 'Air Nippon', 'Aerospatiale',
#        'Ati', 'Malaysian/Air Inter', 'Delta Express', 'Standard Airways',
#        'Casino Express', 'Tnt', 'Antonov Design Bureau',
#        'Trans Canada Airlines', 'Conviasa', 'Freedom Air', 'Ecuatoriana',
#        'Tibet Airlines', 'Virgin Galactic', 'Pb Air', 'Taag',
#        'Atlant-Soyuz Airlines', 'White', 'Civil Air Transport',
#        'American Eagle', 'Saha Air Lines', 'Air Australia', 'Cargolux',
#        'Thai Airasia', 'American Inter Island', 'Scoot', 'Dhl',
#        'Evergreen', 'Oman Air', 'Goair', 'Nigeria Airways',
#        'Virgin Samoa', 'Iberia Express', 'British Caledonian',
#        'Northwest Airlink', 'Australian Air Express', 'Airtran',
#        'Seaboard World', 'Ladeco', 'Psa', 'Pacific Air', 'Air West',
#        'Ethiopian Airlines', 'Jetstar Japan', 'Ank', 'Air Bridge Cargo',
#        'Heavylift', 'Compass Airlines', 'Tower Air', 'Aeromaritime',
#        'Jade Cargo', 'Kunpen', 'Tat', 'Soviet Air Force', 'Jetstar Asia',
#        'Jetstar Hongkong', 'Nordair', 'Bea', 'Arrow Air',
#        'Ansett New Zealand', 'Drax Air', 'Air Atlantic', 'Qubecair',
#        'Atlantic Airlines', 'Huges Airwest', 'Transamerica', 'Quebecair',
#        'Northwest Territorial', 'Air Mauritius', 'Nlm', 'Nok Air',
#        'Cruzeiro', 'Kmv', 'Malev', 'Russian Airforce', 'Iraqi Airways',
#        'Zambia Airways', 'Northeastern', 'Aeroperu', 'Pluna', 'Indigo',
#        'Tunis Air', 'Aeromexico', 'East Line Airlines',
#        'Turkmenistan Airlines', 'Delta Chicago & Southern', 'Avianova',
#        'Douglas Aircraft Company', 'Global Aviation Leasing',
#        'Mcdonnell Douglas', 'Royal Air Force', 'British Eagle',
#        'Republic Airlines', 'Ryukyu Air Commuter', 'A-Net',
#        'Phuket Airlines', 'Ryanair', 'Amakusa', 'Transasia', 'Norwegian',
#        'Air Zaire', 'Jaz', 'Air Jamaica', 'Blank', 'Raf',
#        'Virgin Nigeria', 'Air Madagascar', 'Syrianair', 'Iran Air',
#        'Us Navy', 'Air Ceylon', 'Air Namibia', 'Zambian Airways',
#        'Westjet', 'Bahamasair', 'Channel Air Bridge', 'Buffalo Airways',
#        'Jetblue', 'Iron Annie', 'Panegra', 'Ansett Express',
#        'Fiji Airways', 'Avianca Brazil', 'Dan Air', 'Hongkong Express',
#        'Air Koryo', 'Azul Linhas Aereas', 'Pba', 'Universal Airlines',
#        'Usair', 'Nokscoot', 'Fantasy Aetna', 'Silkair', 'Sands Casino',
#        'Mackey International', 'Mahan', 'Frontier Airlines',
#        'Vietnam Airlines', 'Brussels Airlines', 'Air Congo', 'Comair',
#        'Air Transat', 'Trans Carribean Airways', 'Vasp',
#        'Indian Airforce', 'Allegiant Air', 'Gator Global Flying', 'Taesa',
#        'Tui Airlines', 'Piedmont', 'Royal Jordanian', 'Air Tahiti',
#        'Volaris', 'Western Airlines', 'Novair', 'Cathay Dragon',
#        'Pan American Grace Airway', 'Panair Do Brasil', 'Jettrain',
#        'Icelandair', 'Latam', 'Silkway Airlines', 'Royal Australian Af',
#        'Air America', 'Utair', 'Trump', 'Rossiya', 'Ozark Airlines',
#        'Raaf', 'United Express', 'Allegheny Airlines', 'Sf Airlines',
#        'Air Caraibes', 'Aerocondor', 'Sun Country', 'Finlantic',
#        'Peoplexpress', 'Wow Air', 'Patriots', 'Aero California',
#        'Air Florida', 'Ukranian Airforce', 'Hongkong Airlines',
#        'Ariana Afghan', 'Air Greenland', 'Ukraine International',
#        'Astraeus', 'Spanair', 'Government Of Brunei', 'Air Zimbabwe',
#        'Air Rhodesia', 'Liat', 'Sukhoi Design Bureau', 'Indian Navy',
#        'Hi Fly', 'Royal Thai Air Force', 'Lam Mozambique',
#        'Thomas Cook Airlines', 'Trans Global Airlines', 'Capitol Airways',
#        'Flydubai', 'Real Transportes Aereos', 'Sun Dor',
#        'Saudi Arabian Government', 'Air Cote D Ivoire', 'Avensa',
#        'Kazakhstan Airforce', 'Japan Sdf', 'Hungarian Airforce',
#        'Slovakia Airforce', 'Venezuelan Airforce', 'Tarom', 'Private',
#        'Royal Nepal Airlines', 'Aerovias Q', 'Air Holland', 'Abx Air',
#        'Republic Of Korea Airforc', 'Polet Aviakompania',
#        'South African Airforce', 'Ltu', 'Lockheed', 'Caledonian',
#        'Thomsonfly', 'Mexican Air Force', 'Iceland Air',
#        'Vnukovo Airlines', 'Slovak Airlines', 'British Midland', 'Uat',
#        'Pby Foundation', 'Faucett Peru', 'Sunwing', 'Taca', 'Qatar'],
#       dtype=object)

# %%
airlinegrp.head()
# Out:
#                  total
# AIRLINE
# A-NET                1
# ABX AIR              1
# ADRIA                3
# AER LINGUS          33
# AERO CALIFORNIA      3

# %%
ai_df.describe()
# Out:
#                 ID       PRICE    SHIPPING         TAX
# count   197.000000  197.000000  197.000000  197.000000
# mean   3102.020305   40.896041    2.590863    0.089340
# std    3173.879622   27.181890    4.901747    0.435993
# min       2.000000    0.000000    0.000000    0.000000
# 25%     206.000000   27.200000    0.000000    0.000000
# 50%    1594.000000   32.260000    0.000000    0.000000
# 75%    6836.000000   39.990000    2.700000    0.000000
# max    8940.000000  137.000000   36.510000    2.300000

# %%
# configure elasticsearch

# %%
#exportdf.describe()

# %%
#import pyes
#es1=pyes.ES()
#exportdf["no_index"] = [x+1 for x in range(len(exportdf["ID"]))]
#tmp = exportdf.to_json(orient = "records")
# Load each record into json format before bulk
#df_json= json.loads(tmp)
#print(df_json[0])
# Create an index into elastic search. If we need to create a mapping, we ought to do it here
#index_name = 'cars'
#type_name = 'record'

# Bulk index
#for doc in df_json:
    #es1.index(doc, index_name, type_name,id=doc['no_index'])

# %%
INDEX="aircraft"
TYPE= "models"
#res = es.search(index=INDEX, body={"query":  {"match": {"REGISTRATION": "VR-HOA"}}})
res = es.search(index=INDEX, body={"query":  {"match_phrase": {"REGISTRATION": "VR-HOA"}}})
print('f{} documents found',res['hits']['total'])
for doc in res['hits']['hits']:
    #print(doc)
    print(doc['_id'], doc['_source'])
# Out:
# f{} documents found {'value': 5, 'relation': 'eq'}
# EvQtU3ABxbBv7D59Iuto {'ID': 1073, 'MODEL_NO': 'WID13288', 'DIMAID': None, 'WID': '13288', 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'Blue Box Cathay Pacific L-1011-100 1:400 - NA - ID#13288; 1980s  Colors. With  Chrome  Belly.VR-HOA', 'SIZE': '1:400', 'PRICE': 58.01, 'SHIPPING': 11.0, 'TAX': 0.0, 'COMPANY': 'BLUE BOX', 'ORDEREDFROM': 'ebay:kiet747', 'DATEOFORDER': 1334016000000, 'HangarClub': False, 'PictureID': 1176.0}
# IvQtU3ABxbBv7D59IvNp {'ID': 3743, 'MODEL_NO': 'BBOX101102', 'DIMAID': 0.0, 'WID': '33578', 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'Blue Box Cathay Pacific L-1011-100 1:200 - BBOX101102 - ID#33578; 1980s  Colors.VR-HOA', 'SIZE': '1:200', 'PRICE': 97.0, 'SHIPPING': 0.0, 'TAX': 0.0, 'COMPANY': 'BLUE BOX', 'ORDEREDFROM': 'WAFFLECOLLECTIBLES', 'DATEOFORDER': 1346976000000, 'HangarClub': False, 'PictureID': 3706.0}
# FvUtU3ABxbBv7D59IgFq {'ID': 7959, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 35.0, 'SHIPPING': 0.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'WAFFLECOLLECTIBLES', 'DATEOFORDER': 1538870400000, 'HangarClub': False, 'PictureID': 9791.0}
# JPUtU3ABxbBv7D59IgFq {'ID': 7973, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 39.99, 'SHIPPING': 6.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'EBAY:JIMMY', 'DATEOFORDER': 1538784000000, 'HangarClub': False, 'PictureID': 9791.0}
# JfUtU3ABxbBv7D59IgFq {'ID': 7974, 'MODEL_NO': 'XX4113', 'DIMAID': 76758.0, 'WID': None, 'AIRLINE': 'CATHAY PACIFIC', 'AIRCRAFT_TYPE': 'L1011-100', 'REGISTRATION': 'VR-HOA', 'DESCRIPTION': 'JC Wings CATHAY PACIFIC L-1011-100 1:400 XX4113 "1980s" Colors. With Polished Belly. With Rolling Gears.VR-HOA', 'SIZE': '1:400', 'PRICE': 39.99, 'SHIPPING': 6.0, 'TAX': 0.0, 'COMPANY': 'JC WINGS', 'ORDEREDFROM': 'EBAY:JIMMY', 'DATEOFORDER': 1538784000000, 'HangarClub': False, 'PictureID': 9791.0}

# %%
exportdf["month"]=exportdf["DATEOFORDER"].dt.month
exportdf["year"]=exportdf["DATEOFORDER"].dt.year
exportdf.head()
# Out:
#    ID  MODEL_NO  DIMAID    WID        AIRLINE AIRCRAFT_TYPE REGISTRATION  \
# 0   2  AC18022B     NaN   3873      AIR INDIA      B707-400       VT-DJI
# 1   3  HE502238     0.0  12793     KINGFISHER      A320-200       VT-KFA
# 2   7  DRW55934     0.0  13473  QATAR AIRWAYS      A330-200       A7-ACG
# 3  11    MP5805     0.0  17047      LUFTHANSA      A340-600           NA
# 4  12   AC4XEAJ     NaN  15977          EL AL    B767-300ER       4X-EAJ
#
#                                          DESCRIPTION   SIZE   PRICE  SHIPPING  \
# 0  Aeroclassics Air India B 707-437 1:400 - AC180...  1:400  122.00      20.0
# 1  Herpa Kingfisher Airlines A320-232 1:500 - 502...  1:500   26.00       3.0
# 2  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400   20.95       0.4
# 3  Model Power Lufthansa A340-642 1:500 - 5805 - ...  1:500   14.95       0.4
# 4  Aeroclassics El Al B 767-330ER 1:400 - AC4XEAJ...  1:400   15.00       1.0
#
#    TAX       COMPANY       ORDEREDFROM DATEOFORDER  HangarClub  PictureID  \
# 0  0.0  AEROCLASSICS  EBAY:marketa2218  2011-02-06       False        2.0
# 1  0.0         HERPA              DAC:  2011-02-06       False        3.0
# 2  0.0  DRAGON WINGS      3000toys.com  2011-02-04       False        6.0
# 3  0.0   MODEL POWER      3000TOYS.COM  2011-02-04       False       10.0
# 4  0.0  AEROCLASSICS      JETCOLLECTOR  2011-01-02       False       12.0
#
#    month  year
# 0      2  2011
# 1      2  2011
# 2      2  2011
# 3      2  2011
# 4      1  2011

# %%
exportdf["netprice"]=exportdf["PRICE"]+exportdf["SHIPPING"]+exportdf["TAX"]
purchasesumdf=exportdf.groupby(["year","month"]).agg({"netprice":"sum"})
purchasesumdf.tail(2)
# Out:
#             netprice
# year month
# 2020 1       2323.93
#      2        857.35

# %%
#solddf.head()

# %%
solddf.rename(columns={"Net Recd":"Tot_SP"})
solddf["Tot_CP"]=solddf['price']+solddf["shipping"]+solddf["tax"]
solddf["tot_efees"]=solddf['ListingFee']+solddf["EbayFee"]+solddf["PaypalFee"]+solddf["tax"]
solddf['shippingfees']=solddf['Shipping']+solddf["Insurance"]
#solddf.head()
solddf=solddf.reset_index()
solddf=solddf.groupby(['year','month'],as_index=False).agg({'Listing price':'sum','Net Recd':'sum','ListingFee':'sum'\
                        ,'EbayFee':'sum','PaypalFee':'sum','Insurance':'sum','Shipping':'sum','NetRecd':'sum','profit_loss':'sum'})
#,'EbayFee','PaypalFee','Insurance','Shipping','NetRecd','profit_loss'

solddf.to_csv("E:\Aircraft_Phase_1\db\sold.csv")
solddf.to_csv("E:\Aircraft_Phase_1\db\sold.csv")
solddf.to_json("E:\Aircraft_Phase_1\db\sold.csv",orient='records')

# %%
solddf.head()
# Out:
#    year  month  Listing price  Net Recd  ListingFee  EbayFee  PaypalFee  \
# 0  2011     12          34.00     42.00        0.72     3.06       1.52
# 1  2012      1          95.00    112.85        0.00    10.16       3.88
# 2  2012      2          34.00     42.00        0.00     3.78       1.52
# 3  2012      3         135.38    211.12        0.00     0.00       8.84
# 4  2012      4         928.48   1236.18        0.00    76.07      49.48
#
#    Insurance  Shipping  NetRecd  profit_loss
# 0       1.80      5.34    29.56         2.06
# 1       4.15      6.22    88.44        72.88
# 2       1.85      3.28    31.57         5.47
# 3       6.05     58.18   138.05        21.31
# 4       8.95    250.94   850.74       191.26

# %%
solddf.head()
# Out:
#    year  month  Listing price  Net Recd  ListingFee  EbayFee  PaypalFee  \
# 0  2011     12          34.00     42.00        0.72     3.06       1.52
# 1  2012      1          95.00    112.85        0.00    10.16       3.88
# 2  2012      2          34.00     42.00        0.00     3.78       1.52
# 3  2012      3         135.38    211.12        0.00     0.00       8.84
# 4  2012      4         928.48   1236.18        0.00    76.07      49.48
#
#    Insurance  Shipping  NetRecd  profit_loss
# 0       1.80      5.34    29.56         2.06
# 1       4.15      6.22    88.44        72.88
# 2       1.85      3.28    31.57         5.47
# 3       6.05     58.18   138.05        21.31
# 4       8.95    250.94   850.74       191.26

# %%
    db=client['Aircraft']
    colmodels=db['models']
    colmodels2=db['models2']
#    def modelinvest():
    data={}
    cursor = colmodels.find() 
    #for rec in cursor[:2]:  #slicning in loop to show only two records
     #print (rec)
    aggpipeline =[{ "$group": {"_id": "$AIRLINE", "total": { "$sum": "$PRICE" },"myCount": { "$sum": 1 }}}]
    cursor1=colmodels.aggregate(aggpipeline)

    cursor1
    #for rec in cursor1:
     #   print(rec)
    #print(list(cursor1))    
    summarydf = pd.DataFrame(list(colmodels.aggregate(aggpipeline))).rename(columns={"_id":"Airline","myCount":"ModelCount"})
    data = { "airline":summarydf["Airline"].tolist(),
               "ModelCount":summarydf["ModelCount"].tolist(),
                "total":summarydf["total"].tolist(),
           }
    #print(data)
    test=summarydf.to_json()
    print(test)
    #return jsonify(data)

#investdf = modelinvest()
#investdf.head()
# Out:
# {"Airline":{"0":"IRAN AIR","1":"GULF AIR","2":"AIR INDIA EXPRESS","3":"CHINA SOUTHERN","4":"FEDEX","5":"TAESA","6":"MALEV","7":"UKRANIAN AIRFORCE","8":"AIR COTE D IVOIRE","9":"AIR CARAIBES","10":"MALAYSIA AIRLINES","11":"AIR GREENLAND","12":"AIR PACIFIC","13":"CARGOLUX","14":"NLM","15":"RYANAIR","16":"PEOPLEXPRESS","17":"AIR CANADA","18":"FLYDUBAI","19":"TAT","20":"SOUTH AFRICAN","21":"Saudi Arabian Government","22":"AIR AMERICA","23":"CORSAIR","24":"MEGANTARA","25":"Dragonair","26":"ANA","27":"MONARCH","28":"PBA","29":"CATHAY DRAGON","30":"WHITE","31":"REAL TRANSPORTES AEREOS","32":"JETSTAR HONGKONG","33":"JALWAYS","34":"MANDALA AIRLINES","35":"AEROLINEAS ARGENTINAS","36":"PB AIR","37":"SOVIET AIR FORCE","38":"AMERICA WEST","39":"AMERICAN AIRLINES","40":"AEROPERU","41":"UTA","42":"AUSTRIAN AIRLINES","43":"BMI","44":"TRANS GLOBAL AIRLINES","45":"AIR CHINA","46":"QUEBECAIR","47":"AIR HONGKONG","48":"GERMAINIA","49":"ROYAL AIR FORCE","50":"KINGFISHER","51":"ATLANT-SOYUZ AIRLINES","52":"TRANSAMERICA","53":"EAST LINE AIRLINES","54":"ICELANDAIR","55":"RAAF","56":"ROYAL AIR MAROC","57":"AIR BERLIN","58":"ISRAIR","59":"AVIANCA BRAZIL","60":"IBERIA","61":"MACKEY INTERNATIONAL","62":"SUNWING","63":"MANDARIN","64":"AIR CALIFORNIA","65":"CRUZEIRO","66":"AIR UK","67":"TRANSASIA","68":"Virgin America","69":"ROYAL NEPAL AIRLINES","70":"JET AIRWAYS","71":"SAUDI ARABIAN","72":"TURKISH AIRLINES","73":"VIRGIN NIGERIA","74":"SINGAPORE AIRLINES","75":"TNT","76":"SILKWAY AIRLINES","77":"MYAIR","78":"MERPATI NUSANTARA","79":"UKRAINE INTERNATIONAL","80":"TAROM","81":"AIR EUROPA","82":"TAA","83":"PANAM","84":"AMAKUSA","85":"SAS","86":"ADRIA","87":"FIJI AIRWAYS","88":"HONGKONG AIRLINES","89":"Air Zaire","90":"AIR EUROPE","91":"AIR CONGO","92":"JAPAN ASIA AIRWAYS","93":"SUDAN AIRWAYS","94":"ANSETT AUSTRALIA","95":"SABENA","96":"SPANAIR","97":"AIR NEW ZEALAND","98":"GOAIR","99":"NOVAIR","100":"Biman Bangladesh","101":"VIRGIN NIGERIA AIRWAYS","102":"ATLAS AIR","103":"LTU","104":"JAT","105":"NORTHWEST","106":"QUBECAIR","107":"VIRGIN AUSTRALIA","108":"QATAR AIRWAYS","109":"AEROVIAS Q","110":"ANTONOV DESIGN BUREAU","111":"ROYAL AVIATION","112":"INDIGO","113":"HORIZON AIR","114":"LUFTWAFFE","115":"HEAVYLIFT","116":"AIR WEST","117":"CANADIAN PACIFIC","118":"CEBU PACIFIC","119":"JAA","120":"MEA","121":"Finnair","122":"LIAT","123":"JAPAN SDF","124":"BRANIFF","125":"AIR MAURITIUS","126":"AIR TAHITI","127":"INDIAN AIRFORCE","128":"GHANA AIRWAYS","129":"UAT","130":"COMAIR","131":"AUSTRALIA ASIA AIRLINES","132":"FANTASY","133":"COLUMBIA AIRLINES","134":"FREEDOM AIR","135":"VOLARIS","136":"PACIFIC BLUE","137":"BIMAN BANGLADESH","138":"GOVERNMENT OF BRUNEI","139":"FRONTIER AIRLINES","140":"ALITALIA","141":"EASTERN AIRLINES","142":"Horizon Air","143":"FANTASY AETNA","144":"BRUSSELS AIRLINES","145":"PHILIPPINE AIRLINES","146":"ZAMBIA AIRWAYS","147":"AER LINGUS","148":"INDIAN AIRLINES","149":"GULF TRAVELLER","150":"CONDOR","151":"STANDARD AIRWAYS","152":"ALLEGHENY AIRLINES","153":"NORTHWEST ORIENT","154":"TACA","155":"BRITANNIA AIRWAYS","156":"TUIFLY.COM","157":"CASINO EXPRESS","158":"THOMSONFLY","159":"K MILE","160":"AIR ZAIRE","161":"QANTASLINK","162":"OMAN AIR","163":"VIASA","164":"JAL","165":"TRANS CANADA AIRLINES","166":"PBY FOUNDATION","167":"MASWINGS","168":"PANAIR DO BRASIL","169":"ECUATORIANA","170":"KOREAN AIR","171":"HAINAN AIRLINES","172":"SEABOARD WORLD","173":"TIGER AIRWAYS","174":"LATAM","175":"HUNGARIAN AIRFORCE","176":"DELTA CHICAGO & SOUTHERN","177":"HONGKONG EXPRESS","178":"LANICA","179":"European Aircharter","180":"NAL","181":"TIBET AIRLINES","182":"Hainan Airlines","183":"CANADIAN AIRLINES","184":"AIRBUS","185":"LUXAIR","186":"PELITA AIR","187":"EL AL","188":"CHINA NORTHERN","189":"LADECO","190":"Austrian Airlines","191":"DAN AIR","192":"TOWER AIR","193":"NCA","194":"AIR AUSTRALIA","195":"AUSTRALIAN AIR EXPRESS","196":"RUSSIAN AIRFORCE","197":"NORTHWEST TERRITORIAL","198":"PAN AMERICAN GRACE AIRWAY","199":"SLOVAKIA AIRFORCE","200":"GERMAN CARGO","20 ...

# %%
testdf = pd.DataFrame(data)
testdf=testdf.sort_values(['ModelCount'],ascending=False)
testdf.head(20)
# Out:
#                 airline  ModelCount     total
# 207              QANTAS         320  15589.53
# 444           LUFTHANSA         319  13869.80
# 254      CATHAY PACIFIC         319  17216.41
# 267     BRITISH AIRWAYS         319  15694.90
# 39    AMERICAN AIRLINES         257  12483.48
# 246               DELTA         253  11026.51
# 26                  ANA         250  13151.18
# 74   SINGAPORE AIRLINES         249  11247.03
# 443              UNITED         245  12003.80
# 349                 KLM         229  12385.69
# 83                PANAM         212  10034.94
# 448           AIR INDIA         197   8056.52
# 164                 JAL         160   6461.59
# 477          AIR FRANCE         128   5959.12
# 97      AIR NEW ZEALAND         123   5372.05
# 261             EVA AIR         113   4817.21
# 486               VARIG         112   5580.87
# 416        THAI AIRWAYS         112   3989.95
# 483     VIRGIN ATLANTIC          98   5544.18
# 20        SOUTH AFRICAN          90   4629.56

# %%
cursor = colmodels.find({"AIRLINE":"AIR INDIA"}) 
for rec in cursor[:2]:  #slicning in loop to show only two records
         print (rec)
cursor = colmodels.find({"AIRLINE":"AIR INDIA"}, { "AIRLINE": 1, "AIRCRAFT_TYPE": 1, "REGISTRATION": 1,"_id":0 })
for rec in cursor[:2]:  #slicning in loop to show only two records
         print (rec)
print("++++++++++++++++++")
cursor = colmodels.find({"REGISTRATION":"VT-DJI"}, { "AIRLINE": 1, "AIRCRAFT_TYPE": 1, "REGISTRATION": 1,"_id":0 })
for rec in cursor:  #slicning in loop to show only two records
         print (rec)
# Out:
# {'_id': ObjectId('5e4a8a8656a69c7624df5bc9'), 'ID': 2, 'MODEL_NO': 'AC18022B', 'DIMAID': nan, 'WID': '3873', 'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI', 'DESCRIPTION': 'Aeroclassics Air India B 707-437 1:400 - AC18022B - ID#3873; 1960s - Delivery  Colors. Named  Nanda Devi .VT-DJI', 'SIZE': '1:400', 'PRICE': 122.0, 'SHIPPING': 20.0, 'TAX': 0.0, 'COMPANY': 'AEROCLASSICS', 'ORDEREDFROM': 'EBAY:marketa2218', 'DATEOFORDER': datetime.datetime(2011, 2, 6, 0, 0), 'HangarClub': False, 'PictureID': 2.0}
# {'_id': ObjectId('5e4a8a8656a69c7624df5bd8'), 'ID': 32, 'MODEL_NO': 'IF743003', 'DIMAID': 0.0, 'WID': '21375', 'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B747-300', 'REGISTRATION': 'VT-EPW', 'DESCRIPTION': 'Inflight200 Air India B 747-337SCD 1:200 - IF743003; 1990s  Colors. With Rolling Gears;VT-EPW', 'SIZE': '1:200', 'PRICE': 90.0, 'SHIPPING': 4.0, 'TAX': 0.0, 'COMPANY': 'INFLIGHT200', 'ORDEREDFROM': 'EBAY:JOHANCHAN2004', 'DATEOFORDER': datetime.datetime(2011, 1, 31, 0, 0), 'HangarClub': False, 'PictureID': 32.0}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B747-300', 'REGISTRATION': 'VT-EPW'}
# ++++++++++++++++++
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
# {'AIRLINE': 'AIR INDIA', 'AIRCRAFT_TYPE': 'B707-400', 'REGISTRATION': 'VT-DJI'}
