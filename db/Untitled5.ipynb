# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
uri = 'mongodb+srv://<userid>:<>@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority'
localmongo = Mongoclient('localhost', Port ="27017")
client = MongoClient(uri)
db=client['Aircraft']
colmodels=db['models']
modelsdf = pd.DataFrame(list(colmodels.find()))

# %%
uri = 'mongodb+srv://<userid>:<>@cluster0-omshy.mongodb.net/test?retryWrites=true&w=majority'
client = MongoClient(uri)
db=client['Aircraft']
colmodels=db['models']
modelsdf = pd.DataFrame(list(colmodels.find()))

# %%
db=client['Aircraft']
colmodels=db['models']
modelsdf = pd.DataFrame(list(colmodels.find()))

# %%
modelsdf.head()
# Out:
#                         _id  ID  MODEL_NO  DIMAID    WID        AIRLINE  \
# 0  6482363675257418a88e0f6f   2  AC18022B     NaN   3873      AIR INDIA
# 1  6482363675257418a88e0f70   3  HE502238     0.0  12793     KINGFISHER
# 2  6482363675257418a88e0f71   7  DRW55934     0.0  13473  QATAR AIRWAYS
# 3  6482363675257418a88e0f72  11    MP5805     0.0  17047      LUFTHANSA
# 4  6482363675257418a88e0f73  12   AC4XEAJ     NaN  15977          EL AL
#
#   AIRCRAFT_TYPE REGISTRATION  \
# 0      B707-400       VT-DJI
# 1      A320-200       VT-KFA
# 2      A330-200       A7-ACG
# 3      A340-600           NA
# 4    B767-300ER       4X-EAJ
#
#                                          DESCRIPTION   SIZE   PRICE  SHIPPING  \
# 0  Aeroclassics Air India B 707-437 1:400 - AC180...  1:400  122.00      20.0
# 1  Herpa Kingfisher Airlines A320-232 1:500 - 502...  1:500   26.00       3.0
# 2  Dragon Wings Qatar Airways A330-202 1:400 - 55...  1:400   20.95       0.4
# ...
